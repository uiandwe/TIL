# %%
import tensorflow as tf

x1_data = [73., 93., 89., 96., 73.]
x2_data = [80., 88., 91., 98., 66.]
x3_data = [75., 93., 90., 100., 70]
y_data = [152., 185., 180., 196., 142]

x1 = tf.placeholder(tf.float32)
x2 = tf.placeholder(tf.float32)
x3 = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

w1 = tf.Variable(tf.random_normal([1], name='weight1'))
w2 = tf.Variable(tf.random_normal([1], name='weight2'))
w3 = tf.Variable(tf.random_normal([1], name='weight3'))
b = tf.Variable(tf.random_normal([1], name='bias'))

hypothesis = x1 * w1 + x2 * w2 + x3 * w3 + b

cost = tf.reduce_mean(tf.square(hypothesis - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train],
                                  feed_dict={x1: x1_data, x2:x2_data, x3: x3_data, Y: y_data})
    if step % 10 == 0:
        print(step, "cost:", cost_val, "\nPrediction:", hy_val)
# Out:
# (0, 'cost:', 14093.943, '\nPrediction:', array([36.931503, 64.15499 , 52.77826 , 62.113068, 49.726723],
#       dtype=float32))
# (10, 'cost:', 31.232029, '\nPrediction:', array([141.85527, 190.22707, 177.0193 , 197.40509, 145.88118],
#       dtype=float32))
# (20, 'cost:', 30.959309, '\nPrediction:', array([142.19307, 190.59471, 177.4016 , 197.81804, 146.15486],
#       dtype=float32))
# (30, 'cost:', 30.816074, '\nPrediction:', array([142.21434, 190.58202, 177.40907, 197.82283, 146.13844],
#       dtype=float32))
# (40, 'cost:', 30.67361, '\nPrediction:', array([142.23463, 190.56825, 177.41544, 197.8264 , 146.12123],
#       dtype=float32))
# (50, 'cost:', 30.531887, '\nPrediction:', array([142.25484, 190.55447, 177.42177, 197.82997, 146.10402],
#       dtype=float32))
# (60, 'cost:', 30.390976, '\nPrediction:', array([142.275  , 190.54076, 177.42807, 197.8335 , 146.08688],
#       dtype=float32))
# (70, 'cost:', 30.250824, '\nPrediction:', array([142.29512, 190.5271 , 177.43439, 197.83705, 146.06982],
#       dtype=float32))
# (80, 'cost:', 30.111277, '\nPrediction:', array([142.31519, 190.51343, 177.44066, 197.84055, 146.05278],
#       dtype=float32))
# (90, 'cost:', 29.97261, '\nPrediction:', array([142.33517, 190.49982, 177.4469 , 197.84404, 146.03577],
#       dtype=float32))
# (100, 'cost:', 29.834574, '\nPrediction:', array([142.35513, 190.48624, 177.45314, 197.84753, 146.0188 ],
#       dtype=float32))
# (110, 'cost:', 29.69743, '\nPrediction:', array([142.37503, 190.47272, 177.45938, 197.85104, 146.00192],
#       dtype=float32))
# (120, 'cost:', 29.5608, '\nPrediction:', array([142.39491, 190.45921, 177.46562, 197.85452, 145.98509],
#       dtype=float32))
# (130, 'cost:', 29.42511, '\nPrediction:', array([142.41466, 190.44572, 177.47179, 197.85796, 145.96825],
#       dtype=float32))
# (140, 'cost:', 29.289982, '\nPrediction:', array([142.43442, 190.4323 , 177.47798, 197.8614 , 145.95149],
#       dtype=float32))
# (150, 'cost:', 29.155697, '\nPrediction:', array([142.4541 , 190.41891, 177.48415, 197.86484, 145.93478],
#       dtype=float32))
# (160, 'cost:', 29.022022, '\nPrediction:', array([142.47374, 190.40553, 177.49028, 197.86827, 145.9181 ],
#       dtype=float32))
# (170, 'cost:', 28.889181, '\nPrediction:', array([142.49335, 190.39226, 177.49643, 197.8717 , 145.90152],
#       dtype=float32))
# (180, 'cost:', 28.75687, '\nPrediction:', array([142.51288, 190.37895, 177.50256, 197.87509, 145.88492],
#       dtype=float32))
# (190, 'cost:', 28.625492, '\nPrediction:', array([142.53232, 190.36569, 177.50864, 197.87845, 145.86838],
#       dtype=float32))
# (200, 'cost:', 28.494665, '\nPrediction:', array([142.55176, 190.35248, 177.51472, 197.88184, 145.8519 ],
#       dtype=float32))
# (210, 'cost:', 28.364552, '\nPrediction:', array([142.57114, 190.33928, 177.52078, 197.8852 , 145.83548],
#       dtype=float32))
# (220, 'cost:', 28.235123, '\nPrediction:', array([142.59045, 190.32613, 177.52682, 197.88855, 145.81906],
#       dtype=float32))
# (230, 'cost:', 28.106419, '\nPrediction:', array([142.60976, 190.31305, 177.5329 , 197.89194, 145.80275],
#       dtype=float32))
# (240, 'cost:', 27.97844, '\nPrediction:', array([142.62897, 190.29997, 177.5389 , 197.89525, 145.78645],
#       dtype=float32))
# (250, 'cost:', 27.85111, '\nPrediction:', array([142.64812, 190.28691, 177.54489, 197.89856, 145.77019],
#       dtype=float32))
# (260, 'cost:', 27.724329, '\nPrediction:', array([142.66728, 190.27393, 177.55092, 197.9019 , 145.754  ],
#       dtype=float32))
# (270, 'cost:', 27.598352, '\nPrediction:', array([142.68634, 190.26096, 177.55688, 197.90518, 145.73782],
#       dtype=float32))
# (280, 'cost:', 27.473019, '\nPrediction:', array([142.70535, 190.24799, 177.5628 , 197.90846, 145.72171],
#       dtype=float32))
# (290, 'cost:', 27.348297, '\nPrediction:', array([142.72435, 190.2351 , 177.56879, 197.91177, 145.70564],
#       dtype=float32))
# (300, 'cost:', 27.224339, '\nPrediction:', array([142.74327, 190.22224, 177.57472, 197.91505, 145.68964],
#       dtype=float32))
# (310, 'cost:', 27.100973, '\nPrediction:', array([142.76213, 190.2094 , 177.58061, 197.91829, 145.67363],
#       dtype=float32))
# (320, 'cost:', 26.978283, '\nPrediction:', array([142.78096, 190.19661, 177.58653, 197.92155, 145.6577 ],
#       dtype=float32))
# (330, 'cost:', 26.856256, '\nPrediction:', array([142.79971, 190.18382, 177.59239, 197.92476, 145.6418 ],
#       dtype=float32))
# (340, 'cost:', 26.734833, '\nPrediction:', array([142.81845, 190.1711 , 177.59827, 197.928  , 145.62596],
#       dtype=float32))
# (350, 'cost:', 26.614101, '\nPrediction:', array([142.83713, 190.15842, 177.60416, 197.93123, 145.61017],
#       dtype=float32))
# (360, 'cost:', 26.494019, '\nPrediction:', array([142.85571, 190.14572, 177.60994, 197.93439, 145.59436],
#       dtype=float32))
# (370, 'cost:', 26.374546, '\nPrediction:', array([142.87431, 190.13312, 177.61578, 197.93759, 145.57867],
#       dtype=float32))
# (380, 'cost:', 26.25565, '\nPrediction:', array([142.89287, 190.12053, 177.62161, 197.94081, 145.56302],
#       dtype=float32))
# (390, 'cost:', 26.137583, '\nPrediction:', array([142.9113 , 190.10796, 177.62737, 197.94395, 145.54738],
#       dtype=float32))
# (400, 'cost:', 26.019958, '\nPrediction:', array([142.92973, 190.09541, 177.63316, 197.94713, 145.5318 ],
#       dtype=float32))
# (410, 'cost:', 25.902966, '\nPrediction:', array([142.94814, 190.08293, 177.63893, 197.95029, 145.51627],
#       dtype=float32))
# (420, 'cost:', 25.786701, '\nPrediction:', array([142.96645, 190.07047, 177.64465, 197.9534 , 145.50076],
#       dtype=float32))
# (430, 'cost:', 25.670935, '\nPrediction:', array([142.98474, 190.05803, 177.6504 , 197.95654, 145.48532],
#       dtype=float32))
# (440, 'cost:', 25.555891, '\nPrediction:', array([143.00296, 190.04564, 177.65613, 197.95966, 145.46991],
#       dtype=float32))
# (450, 'cost:', 25.441347, '\nPrediction:', array([143.02116, 190.03326, 177.66182, 197.96278, 145.45454],
#       dtype=float32))
# (460, 'cost:', 25.327538, '\nPrediction:', array([143.03929, 190.02095, 177.66753, 197.9659 , 145.43922],
#       dtype=float32))
# (470, 'cost:', 25.214184, '\nPrediction:', array([143.05737, 190.00862, 177.67317, 197.96893, 145.42392],
#       dtype=float32))
# (480, 'cost:', 25.10155, '\nPrediction:', array([143.07542, 189.99638, 177.67885, 197.97203, 145.40869],
#       dtype=float32))
# (490, 'cost:', 24.989477, '\nPrediction:', array([143.09343, 189.98416, 177.68451, 197.97513, 145.39351],
#       dtype=float32))
# (500, 'cost:', 24.87799, '\nPrediction:', array([143.11136, 189.97194, 177.6901 , 197.97815, 145.37833],
#       dtype=float32))
# (510, 'cost:', 24.767128, '\nPrediction:', array([143.12927, 189.9598 , 177.69574, 197.98122, 145.36325],
#       dtype=float32))
# (520, 'cost:', 24.656824, '\nPrediction:', array([143.1471 , 189.94763, 177.70132, 197.98422, 145.34814],
#       dtype=float32))
# (530, 'cost:', 24.547108, '\nPrediction:', array([143.16492, 189.93553, 177.70692, 197.98729, 145.33315],
#       dtype=float32))
# (540, 'cost:', 24.437931, '\nPrediction:', array([143.1827 , 189.92348, 177.71251, 197.99031, 145.31816],
#       dtype=float32))
# (550, 'cost:', 24.329395, '\nPrediction:', array([143.20036, 189.91139, 177.71802, 197.99326, 145.30319],
#       dtype=float32))
# (560, 'cost:', 24.22149, '\nPrediction:', array([143.21803, 189.89941, 177.72359, 197.99629, 145.28831],
#       dtype=float32))
# (570, 'cost:', 24.114033, '\nPrediction:', array([143.23569, 189.88747, 177.72913, 197.9993 , 145.27347],
#       dtype=float32))
# (580, 'cost:', 24.007282, '\nPrediction:', array([143.25322, 189.8755 , 177.73462, 198.00226, 145.25864],
#       dtype=float32))
# (590, 'cost:', 23.900883, '\nPrediction:', array([143.27077, 189.86359, 177.74014, 198.00522, 145.24385],
#       dtype=float32))
# (600, 'cost:', 23.795227, '\nPrediction:', array([143.28825, 189.85173, 177.74562, 198.0082 , 145.22913],
#       dtype=float32))
# (610, 'cost:', 23.69012, '\nPrediction:', array([143.30566, 189.83987, 177.7511 , 198.01112, 145.21443],
#       dtype=float32))
# (620, 'cost:', 23.585495, '\nPrediction:', array([143.32306, 189.82805, 177.75655, 198.01405, 145.19978],
#       dtype=float32))
# (630, 'cost:', 23.481485, '\nPrediction:', array([143.3404 , 189.81627, 177.76198, 198.01697, 145.18517],
#       dtype=float32))
# (640, 'cost:', 23.377998, '\nPrediction:', array([143.35771, 189.80453, 177.76744, 198.01993, 145.17062],
#       dtype=float32))
# (650, 'cost:', 23.27514, '\nPrediction:', array([143.37491, 189.79279, 177.77281, 198.02277, 145.15607],
#       dtype=float32))
# (660, 'cost:', 23.172667, '\nPrediction:', array([143.39214, 189.7811 , 177.77823, 198.02568, 145.14157],
#       dtype=float32))
# (670, 'cost:', 23.07087, '\nPrediction:', array([143.4093 , 189.76945, 177.78365, 198.02861, 145.12715],
#       dtype=float32))
# (680, 'cost:', 22.96952, '\nPrediction:', array([143.4264 , 189.7578 , 177.78899, 198.03145, 145.11273],
#       dtype=float32))
# (690, 'cost:', 22.868866, '\nPrediction:', array([143.44347, 189.74623, 177.79436, 198.03435, 145.09837],
#       dtype=float32))
# (700, 'cost:', 22.76849, '\nPrediction:', array([143.46051, 189.73465, 177.79971, 198.03717, 145.08405],
#       dtype=float32))
# (710, 'cost:', 22.66885, '\nPrediction:', array([143.47748, 189.72311, 177.80502, 198.04002, 145.06976],
#       dtype=float32))
# (720, 'cost:', 22.569721, '\nPrediction:', array([143.49438, 189.71161, 177.81036, 198.04286, 145.0555 ],
#       dtype=float32))
# (730, 'cost:', 22.471031, '\nPrediction:', array([143.51129, 189.70013, 177.81566, 198.04568, 145.0413 ],
#       dtype=float32))
# (740, 'cost:', 22.372868, '\nPrediction:', array([143.52815, 189.6887 , 177.82097, 198.04851, 145.02715],
#       dtype=float32))
# (750, 'cost:', 22.27531, '\nPrediction:', array([143.5449 , 189.67726, 177.82622, 198.05128, 145.01299],
#       dtype=float32))
# (760, 'cost:', 22.178143, '\nPrediction:', array([143.5617 , 189.6659 , 177.8315 , 198.05411, 144.99893],
#       dtype=float32))
# (770, 'cost:', 22.081589, '\nPrediction:', array([143.5784 , 189.65453, 177.83673, 198.0569 , 144.98486],
#       dtype=float32))
# (780, 'cost:', 21.985537, '\nPrediction:', array([143.59506, 189.6432 , 177.84198, 198.0597 , 144.97086],
#       dtype=float32))
# (790, 'cost:', 21.890009, '\nPrediction:', array([143.61168, 189.63191, 177.84718, 198.06244, 144.9569 ],
#       dtype=float32))
# (800, 'cost:', 21.794922, '\nPrediction:', array([143.62827, 189.62065, 177.8524 , 198.0652 , 144.94296],
#       dtype=float32))
# (810, 'cost:', 21.700397, '\nPrediction:', array([143.6448 , 189.60944, 177.85762, 198.06798, 144.92908],
#       dtype=float32))
# (820, 'cost:', 21.606304, '\nPrediction:', array([143.66129, 189.5982 , 177.86278, 198.07068, 144.9152 ],
#       dtype=float32))
# (830, 'cost:', 21.512802, '\nPrediction:', array([143.67775, 189.58707, 177.86797, 198.07346, 144.90141],
#       dtype=float32))
# (840, 'cost:', 21.41975, '\nPrediction:', array([143.69415, 189.57593, 177.87314, 198.07617, 144.88765],
#       dtype=float32))
# (850, 'cost:', 21.327206, '\nPrediction:', array([143.7105 , 189.56479, 177.87825, 198.07887, 144.8739 ],
#       dtype=float32))
# (860, 'cost:', 21.235125, '\nPrediction:', array([143.72682, 189.55371, 177.88338, 198.08157, 144.86021],
#       dtype=float32))
# (870, 'cost:', 21.14355, '\nPrediction:', array([143.74309, 189.54266, 177.88852, 198.08427, 144.84654],
#       dtype=float32))
# (880, 'cost:', 21.05241, '\nPrediction:', array([143.75932, 189.53162, 177.89362, 198.08696, 144.83293],
#       dtype=float32))
# (890, 'cost:', 20.96183, '\nPrediction:', array([143.7755 , 189.52061, 177.89867, 198.08961, 144.81934],
#       dtype=float32))
# (900, 'cost:', 20.871698, '\nPrediction:', array([143.79167, 189.50969, 177.90378, 198.09232, 144.80582],
#       dtype=float32))
# (910, 'cost:', 20.781971, '\nPrediction:', array([143.80775, 189.4987 , 177.90883, 198.09492, 144.7923 ],
#       dtype=float32))
# (920, 'cost:', 20.692823, '\nPrediction:', array([143.82382, 189.48781, 177.91386, 198.0976 , 144.77884],
#       dtype=float32))
# (930, 'cost:', 20.604065, '\nPrediction:', array([143.83986, 189.47694, 177.91893, 198.10025, 144.76541],
#       dtype=float32))
# (940, 'cost:', 20.51585, '\nPrediction:', array([143.85582, 189.46608, 177.92393, 198.10287, 144.75201],
#       dtype=float32))
# (950, 'cost:', 20.428036, '\nPrediction:', array([143.87177, 189.45526, 177.92896, 198.1055 , 144.73866],
#       dtype=float32))
# (960, 'cost:', 20.34077, '\nPrediction:', array([143.88765, 189.44447, 177.93394, 198.10811, 144.72536],
#       dtype=float32))
# (970, 'cost:', 20.253933, '\nPrediction:', array([143.9035 , 189.43373, 177.93896, 198.11073, 144.71208],
#       dtype=float32))
# (980, 'cost:', 20.167536, '\nPrediction:', array([143.91928, 189.42296, 177.9439 , 198.11328, 144.6988 ],
#       dtype=float32))
# (990, 'cost:', 20.081524, '\nPrediction:', array([143.93509, 189.41228, 177.9489 , 198.1159 , 144.68562],
#       dtype=float32))
# (1000, 'cost:', 19.996037, '\nPrediction:', array([143.9508 , 189.40158, 177.95383, 198.11847, 144.67245],
#       dtype=float32))
# (1010, 'cost:', 19.911037, '\nPrediction:', array([143.96648, 189.39093, 177.95876, 198.12103, 144.65932],
#       dtype=float32))
# (1020, 'cost:', 19.826431, '\nPrediction:', array([143.98213, 189.38031, 177.96367, 198.12358, 144.64624],
#       dtype=float32))
# (1030, 'cost:', 19.742283, '\nPrediction:', array([143.99773, 189.3697 , 177.96858, 198.12613, 144.63318],
#       dtype=float32))
# (1040, 'cost:', 19.658588, '\nPrediction:', array([144.01328, 189.35913, 177.97348, 198.12868, 144.62013],
#       dtype=float32))
# (1050, 'cost:', 19.575352, '\nPrediction:', array([144.02881, 189.34862, 177.97836, 198.1312 , 144.60718],
#       dtype=float32))
# (1060, 'cost:', 19.49254, '\nPrediction:', array([144.04428, 189.3381 , 177.98325, 198.13373, 144.59422],
#       dtype=float32))
# (1070, 'cost:', 19.410198, '\nPrediction:', array([144.0597 , 189.3276 , 177.9881 , 198.13623, 144.5813 ],
#       dtype=float32))
# (1080, 'cost:', 19.328176, '\nPrediction:', array([144.07513, 189.31717, 177.99297, 198.13876, 144.56845],
#       dtype=float32))
# (1090, 'cost:', 19.246653, '\nPrediction:', array([144.09047, 189.30672, 177.99777, 198.14122, 144.55559],
#       dtype=float32))
# (1100, 'cost:', 19.165577, '\nPrediction:', array([144.1058 , 189.29634, 178.00261, 198.14374, 144.5428 ],
#       dtype=float32))
# (1110, 'cost:', 19.08493, '\nPrediction:', array([144.12106, 189.28595, 178.00739, 198.14618, 144.53003],
#       dtype=float32))
# (1120, 'cost:', 19.004707, '\nPrediction:', array([144.13632, 189.27563, 178.0122 , 198.14868, 144.51732],
#       dtype=float32))
# (1130, 'cost:', 18.924908, '\nPrediction:', array([144.1515 , 189.2653 , 178.017  , 198.15114, 144.50462],
#       dtype=float32))
# (1140, 'cost:', 18.845499, '\nPrediction:', array([144.16667, 189.25502, 178.02177, 198.15361, 144.49196],
#       dtype=float32))
# (1150, 'cost:', 18.766548, '\nPrediction:', array([144.18178, 189.24475, 178.02652, 198.15604, 144.47934],
#       dtype=float32))
# (1160, 'cost:', 18.68798, '\nPrediction:', array([144.19687, 189.23453, 178.03128, 198.15848, 144.46677],
#       dtype=float32))
# (1170, 'cost:', 18.609907, '\nPrediction:', array([144.21188, 189.22433, 178.03603, 198.16089, 144.45421],
#       dtype=float32))
# (1180, 'cost:', 18.532183, '\nPrediction:', array([144.22688, 189.21414, 178.04073, 198.16331, 144.4417 ],
#       dtype=float32))
# (1190, 'cost:', 18.454857, '\nPrediction:', array([144.24184, 189.20398, 178.04543, 198.16571, 144.42921],
#       dtype=float32))
# (1200, 'cost:', 18.377909, '\nPrediction:', array([144.25677, 189.19388, 178.05017, 198.16814, 144.41676],
#       dtype=float32))
# (1210, 'cost:', 18.301395, '\nPrediction:', array([144.27164, 189.18375, 178.05484, 198.17052, 144.40434],
#       dtype=float32))
# (1220, 'cost:', 18.225391, '\nPrediction:', array([144.28647, 189.1737 , 178.05951, 198.17291, 144.39197],
#       dtype=float32))
# (1230, 'cost:', 18.14963, '\nPrediction:', array([144.30127, 189.16364, 178.06416, 198.17526, 144.37962],
#       dtype=float32))
# (1240, 'cost:', 18.074368, '\nPrediction:', array([144.31602, 189.15363, 178.06882, 198.17763, 144.36732],
#       dtype=float32))
# (1250, 'cost:', 17.999464, '\nPrediction:', array([144.33075, 189.14363, 178.07347, 198.18001, 144.35506],
#       dtype=float32))
# (1260, 'cost:', 17.924915, '\nPrediction:', array([144.34544, 189.13367, 178.0781 , 198.18234, 144.34282],
#       dtype=float32))
# (1270, 'cost:', 17.85079, '\nPrediction:', array([144.3601 , 189.12373, 178.08272, 198.18471, 144.33064],
#       dtype=float32))
# (1280, 'cost:', 17.777073, '\nPrediction:', array([144.3747 , 189.11382, 178.08731, 198.18703, 144.31844],
#       dtype=float32))
# (1290, 'cost:', 17.703709, '\nPrediction:', array([144.38928, 189.10394, 178.0919 , 198.18935, 144.30632],
#       dtype=float32))
# (1300, 'cost:', 17.630714, '\nPrediction:', array([144.40381, 189.09406, 178.0965 , 198.19167, 144.29422],
#       dtype=float32))
# (1310, 'cost:', 17.558254, '\nPrediction:', array([144.41829, 189.08426, 178.10106, 198.19397, 144.28217],
#       dtype=float32))
# (1320, 'cost:', 17.486027, '\nPrediction:', array([144.43274, 189.07442, 178.1056 , 198.19627, 144.27013],
#       dtype=float32))
# (1330, 'cost:', 17.414223, '\nPrediction:', array([144.44716, 189.06465, 178.11017, 198.19856, 144.25813],
#       dtype=float32))
# (1340, 'cost:', 17.342798, '\nPrediction:', array([144.46155, 189.0549 , 178.11469, 198.20087, 144.24617],
#       dtype=float32))
# (1350, 'cost:', 17.271763, '\nPrediction:', array([144.47588, 189.04517, 178.11922, 198.20312, 144.23425],
#       dtype=float32))
# (1360, 'cost:', 17.201023, '\nPrediction:', array([144.49017, 189.03543, 178.12372, 198.20538, 144.22234],
#       dtype=float32))
# (1370, 'cost:', 17.130772, '\nPrediction:', array([144.50444, 189.02577, 178.12822, 198.20766, 144.2105 ],
#       dtype=float32))
# (1380, 'cost:', 17.060785, '\nPrediction:', array([144.51866, 189.0161 , 178.13269, 198.20988, 144.19864],
#       dtype=float32))
# (1390, 'cost:', 16.991266, '\nPrediction:', array([144.53288, 189.00653, 178.1372 , 198.21217, 144.18689],
#       dtype=float32))
# (1400, 'cost:', 16.92197, '\nPrediction:', array([144.54703, 188.99687, 178.14163, 198.21439, 144.1751 ],
#       dtype=float32))
# (1410, 'cost:', 16.853148, '\nPrediction:', array([144.56116, 188.98732, 178.1461 , 198.21663, 144.16339],
#       dtype=float32))
# (1420, 'cost:', 16.784712, '\nPrediction:', array([144.57521, 188.97777, 178.15053, 198.21883, 144.15167],
#       dtype=float32))
# (1430, 'cost:', 16.71657, '\nPrediction:', array([144.58925, 188.96823, 178.15497, 198.22104, 144.14   ],
#       dtype=float32))
# (1440, 'cost:', 16.64883, '\nPrediction:', array([144.60326, 188.95874, 178.1594 , 198.22325, 144.12839],
#       dtype=float32))
# (1450, 'cost:', 16.581402, '\nPrediction:', array([144.61722, 188.94925, 178.16379, 198.22543, 144.11678],
#       dtype=float32))
# (1460, 'cost:', 16.514332, '\nPrediction:', array([144.63116, 188.9398 , 178.1682 , 198.22765, 144.10522],
#       dtype=float32))
# (1470, 'cost:', 16.447641, '\nPrediction:', array([144.64505, 188.93037, 178.17258, 198.22981, 144.09369],
#       dtype=float32))
# (1480, 'cost:', 16.381252, '\nPrediction:', array([144.65892, 188.92097, 178.17694, 198.23198, 144.08218],
#       dtype=float32))
# (1490, 'cost:', 16.31529, '\nPrediction:', array([144.67273, 188.9116 , 178.18132, 198.23413, 144.07074],
#       dtype=float32))
# (1500, 'cost:', 16.249676, '\nPrediction:', array([144.68651, 188.90227, 178.18567, 198.2363 , 144.0593 ],
#       dtype=float32))
# (1510, 'cost:', 16.184303, '\nPrediction:', array([144.70027, 188.89293, 178.19002, 198.23845, 144.0479 ],
#       dtype=float32))
# (1520, 'cost:', 16.119345, '\nPrediction:', array([144.71397, 188.88362, 178.19434, 198.24059, 144.03651],
#       dtype=float32))
# (1530, 'cost:', 16.054737, '\nPrediction:', array([144.72766, 188.87436, 178.19867, 198.24274, 144.0252 ],
#       dtype=float32))
# (1540, 'cost:', 15.990416, '\nPrediction:', array([144.7413 , 188.8651 , 178.20296, 198.24484, 144.01389],
#       dtype=float32))
# (1550, 'cost:', 15.92648, '\nPrediction:', array([144.7549 , 188.85587, 178.20726, 198.24696, 144.00261],
#       dtype=float32))
# (1560, 'cost:', 15.862828, '\nPrediction:', array([144.76848, 188.84666, 178.21155, 198.24907, 143.99136],
#       dtype=float32))
# (1570, 'cost:', 15.799609, '\nPrediction:', array([144.782  , 188.8375 , 178.21582, 198.25117, 143.98016],
#       dtype=float32))
# (1580, 'cost:', 15.736606, '\nPrediction:', array([144.79552, 188.82834, 178.2201 , 198.25328, 143.969  ],
#       dtype=float32))
# (1590, 'cost:', 15.673998, '\nPrediction:', array([144.80898, 188.81921, 178.22433, 198.25536, 143.95784],
#       dtype=float32))
# (1600, 'cost:', 15.611725, '\nPrediction:', array([144.8224 , 188.81012, 178.22859, 198.25745, 143.94673],
#       dtype=float32))
# (1610, 'cost:', 15.549759, '\nPrediction:', array([144.8358 , 188.80104, 178.23282, 198.25952, 143.93565],
#       dtype=float32))
# (1620, 'cost:', 15.488043, '\nPrediction:', array([144.84915, 188.79195, 178.23701, 198.26155, 143.92458],
#       dtype=float32))
# (1630, 'cost:', 15.426725, '\nPrediction:', array([144.86249, 188.78293, 178.24124, 198.26363, 143.91357],
#       dtype=float32))
# (1640, 'cost:', 15.365771, '\nPrediction:', array([144.87576, 188.77393, 178.24542, 198.26567, 143.90257],
#       dtype=float32))
# (1650, 'cost:', 15.305069, '\nPrediction:', array([144.88902, 188.76494, 178.24963, 198.26772, 143.89163],
#       dtype=float32))
# (1660, 'cost:', 15.244696, '\nPrediction:', array([144.90224, 188.75597, 178.2538 , 198.26974, 143.88069],
#       dtype=float32))
# (1670, 'cost:', 15.184637, '\nPrediction:', array([144.91542, 188.74702, 178.25797, 198.27177, 143.86978],
#       dtype=float32))
# (1680, 'cost:', 15.124934, '\nPrediction:', array([144.92857, 188.73813, 178.26213, 198.2738 , 143.85893],
#       dtype=float32))
# (1690, 'cost:', 15.065538, '\nPrediction:', array([144.94168, 188.72923, 178.26627, 198.27582, 143.8481 ],
#       dtype=float32))
# (1700, 'cost:', 15.006345, '\nPrediction:', array([144.95479, 188.72037, 178.27043, 198.27783, 143.8373 ],
#       dtype=float32))
# (1710, 'cost:', 14.947576, '\nPrediction:', array([144.96782, 188.71152, 178.27452, 198.2798 , 143.82652],
#       dtype=float32))
# (1720, 'cost:', 14.889046, '\nPrediction:', array([144.98083, 188.70268, 178.27866, 198.2818 , 143.81578],
#       dtype=float32))
# (1730, 'cost:', 14.83089, '\nPrediction:', array([144.9938 , 188.6939 , 178.28275, 198.28377, 143.80507],
#       dtype=float32))
# (1740, 'cost:', 14.772987, '\nPrediction:', array([145.00676, 188.68512, 178.28683, 198.28575, 143.79439],
#       dtype=float32))
# (1750, 'cost:', 14.715422, '\nPrediction:', array([145.01965, 188.67636, 178.29091, 198.2877 , 143.78372],
#       dtype=float32))
# (1760, 'cost:', 14.658144, '\nPrediction:', array([145.03253, 188.66763, 178.295  , 198.28967, 143.77312],
#       dtype=float32))
# (1770, 'cost:', 14.601199, '\nPrediction:', array([145.04538, 188.65895, 178.29906, 198.29164, 143.76253],
#       dtype=float32))
# (1780, 'cost:', 14.544482, '\nPrediction:', array([145.0582 , 188.65027, 178.30312, 198.29358, 143.75197],
#       dtype=float32))
# (1790, 'cost:', 14.488169, '\nPrediction:', array([145.07095, 188.64162, 178.30714, 198.29552, 143.74144],
#       dtype=float32))
# (1800, 'cost:', 14.432033, '\nPrediction:', array([145.08371, 188.63298, 178.31119, 198.29745, 143.73094],
#       dtype=float32))
# (1810, 'cost:', 14.37621, '\nPrediction:', array([145.09642, 188.62436, 178.3152 , 198.29938, 143.72046],
#       dtype=float32))
# (1820, 'cost:', 14.320702, '\nPrediction:', array([145.10909, 188.61575, 178.3192 , 198.30128, 143.71   ],
#       dtype=float32))
# (1830, 'cost:', 14.265518, '\nPrediction:', array([145.12172, 188.6072 , 178.3232 , 198.30319, 143.6996 ],
#       dtype=float32))
# (1840, 'cost:', 14.210596, '\nPrediction:', array([145.13434, 188.59866, 178.32718, 198.3051 , 143.68922],
#       dtype=float32))
# (1850, 'cost:', 14.155928, '\nPrediction:', array([145.14691, 188.59013, 178.33118, 198.30699, 143.67886],
#       dtype=float32))
# (1860, 'cost:', 14.101545, '\nPrediction:', array([145.15947, 188.58163, 178.33516, 198.3089 , 143.66855],
#       dtype=float32))
# (1870, 'cost:', 14.047495, '\nPrediction:', array([145.17197, 188.57315, 178.33911, 198.31078, 143.65825],
#       dtype=float32))
# (1880, 'cost:', 13.9937, '\nPrediction:', array([145.18445, 188.5647 , 178.34306, 198.31265, 143.648  ],
#       dtype=float32))
# (1890, 'cost:', 13.940153, '\nPrediction:', array([145.1969 , 188.55626, 178.34698, 198.3145 , 143.63776],
#       dtype=float32))
# (1900, 'cost:', 13.886963, '\nPrediction:', array([145.2093 , 188.54787, 178.35094, 198.31638, 143.62755],
#       dtype=float32))
# (1910, 'cost:', 13.833966, '\nPrediction:', array([145.2217 , 188.53947, 178.35486, 198.31822, 143.61737],
#       dtype=float32))
# (1920, 'cost:', 13.781303, '\nPrediction:', array([145.23404, 188.53111, 178.35876, 198.32007, 143.60722],
#       dtype=float32))
# (1930, 'cost:', 13.72892, '\nPrediction:', array([145.24634, 188.52275, 178.36264, 198.3219 , 143.59709],
#       dtype=float32))
# (1940, 'cost:', 13.67679, '\nPrediction:', array([145.25864, 188.51445, 178.36655, 198.32375, 143.58702],
#       dtype=float32))
# (1950, 'cost:', 13.624908, '\nPrediction:', array([145.27089, 188.50615, 178.37042, 198.32556, 143.57695],
#       dtype=float32))
# (1960, 'cost:', 13.573374, '\nPrediction:', array([145.2831 , 188.49788, 178.3743 , 198.3274 , 143.56693],
#       dtype=float32))
# (1970, 'cost:', 13.522024, '\nPrediction:', array([145.29527, 188.4896 , 178.37814, 198.3292 , 143.5569 ],
#       dtype=float32))
# (1980, 'cost:', 13.470978, '\nPrediction:', array([145.30743, 188.48138, 178.382  , 198.331  , 143.54692],
#       dtype=float32))
# (1990, 'cost:', 13.420149, '\nPrediction:', array([145.31956, 188.47316, 178.38585, 198.3328 , 143.53697],
#       dtype=float32))
# (2000, 'cost:', 13.369679, '\nPrediction:', array([145.33165, 188.46498, 178.38968, 198.3346 , 143.52707],
#       dtype=float32))

# %%
x_data = [[73.,80.,75.], [93., 88.,93.], [89.,91.,90.],
          [96.,98.,100.], [73.,66.,70] ]
y_data = [[152.], [185.], [180.], [196.], [142]]

X = tf.placeholder(tf.float32, shape=[None,3])
Y = tf.placeholder(tf.float32, shape=[None,1])

w = tf.Variable(tf.random_normal([3,1], name='weight'))
b = tf.Variable(tf.random_normal([1], name='bias'))

hypothesis = tf.matmul(X, w)+b

cost = tf.reduce_mean(tf.square(hypothesis - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train],
                                  feed_dict={X: x_data, Y: y_data})
    if step % 10 == 0:
        print(step, "cost:", cost_val, "\nPrediction:", hy_val)
# Out:
# (0, 'cost:', 22706.81, '\nPrediction:', array([[16.290903],
#        [25.08349 ],
#        [22.088007],
#        [22.40698 ],
#        [21.695845]], dtype=float32))
# (10, 'cost:', 2.4640503, '\nPrediction:', array([[149.59033],
#        [185.28967],
#        [179.94699],
#        [194.3111 ],
#        [143.89067]], dtype=float32))
# (20, 'cost:', 2.2462466, '\nPrediction:', array([[149.99876],
#        [185.77089],
#        [180.42613],
#        [194.83257],
#        [144.25555]], dtype=float32))
# (30, 'cost:', 2.2363186, '\nPrediction:', array([[150.00511],
#        [185.7688 ],
#        [180.42912],
#        [194.8355 ],
#        [144.25183]], dtype=float32))
# (40, 'cost:', 2.2264326, '\nPrediction:', array([[150.01022],
#        [185.76526],
#        [180.43066],
#        [194.83684],
#        [144.24698]], dtype=float32))
# (50, 'cost:', 2.2166228, '\nPrediction:', array([[150.01535],
#        [185.76176],
#        [180.4322 ],
#        [194.8382 ],
#        [144.24219]], dtype=float32))
# (60, 'cost:', 2.206862, '\nPrediction:', array([[150.02043],
#        [185.75826],
#        [180.43373],
#        [194.83954],
#        [144.23738]], dtype=float32))
# (70, 'cost:', 2.1971545, '\nPrediction:', array([[150.0255 ],
#        [185.75476],
#        [180.43524],
#        [194.84088],
#        [144.23259]], dtype=float32))
# (80, 'cost:', 2.1874974, '\nPrediction:', array([[150.03055],
#        [185.75125],
#        [180.43677],
#        [194.8422 ],
#        [144.2278 ]], dtype=float32))
# (90, 'cost:', 2.177893, '\nPrediction:', array([[150.0356 ],
#        [185.74779],
#        [180.4383 ],
#        [194.84354],
#        [144.22304]], dtype=float32))
# (100, 'cost:', 2.1683464, '\nPrediction:', array([[150.04063],
#        [185.74431],
#        [180.4398 ],
#        [194.84485],
#        [144.21829]], dtype=float32))
# (110, 'cost:', 2.1588235, '\nPrediction:', array([[150.04565],
#        [185.74083],
#        [180.44131],
#        [194.84619],
#        [144.21355]], dtype=float32))
# (120, 'cost:', 2.149379, '\nPrediction:', array([[150.05066],
#        [185.73738],
#        [180.44281],
#        [194.84749],
#        [144.20882]], dtype=float32))
# (130, 'cost:', 2.1399713, '\nPrediction:', array([[150.05565],
#        [185.73395],
#        [180.44432],
#        [194.84883],
#        [144.2041 ]], dtype=float32))
# (140, 'cost:', 2.1306102, '\nPrediction:', array([[150.06064],
#        [185.73051],
#        [180.4458 ],
#        [194.85014],
#        [144.1994 ]], dtype=float32))
# (150, 'cost:', 2.121304, '\nPrediction:', array([[150.06558],
#        [185.72708],
#        [180.44728],
#        [194.85144],
#        [144.19469]], dtype=float32))
# (160, 'cost:', 2.1120667, '\nPrediction:', array([[150.07053],
#        [185.72368],
#        [180.44878],
#        [194.85275],
#        [144.19002]], dtype=float32))
# (170, 'cost:', 2.1028583, '\nPrediction:', array([[150.07547],
#        [185.72028],
#        [180.45026],
#        [194.85408],
#        [144.18536]], dtype=float32))
# (180, 'cost:', 2.09371, '\nPrediction:', array([[150.08037],
#        [185.71686],
#        [180.45172],
#        [194.85536],
#        [144.1807 ]], dtype=float32))
# (190, 'cost:', 2.0846057, '\nPrediction:', array([[150.08528],
#        [185.71349],
#        [180.45322],
#        [194.85667],
#        [144.17606]], dtype=float32))
# (200, 'cost:', 2.075536, '\nPrediction:', array([[150.0902 ],
#        [185.7101 ],
#        [180.45468],
#        [194.85797],
#        [144.17143]], dtype=float32))
# (210, 'cost:', 2.0665298, '\nPrediction:', array([[150.09506],
#        [185.70673],
#        [180.45615],
#        [194.85927],
#        [144.16681]], dtype=float32))
# (220, 'cost:', 2.0575538, '\nPrediction:', array([[150.09995],
#        [185.70337],
#        [180.45761],
#        [194.86057],
#        [144.1622 ]], dtype=float32))
# (230, 'cost:', 2.0486608, '\nPrediction:', array([[150.10478],
#        [185.70001],
#        [180.45906],
#        [194.86183],
#        [144.15761]], dtype=float32))
# (240, 'cost:', 2.0397952, '\nPrediction:', array([[150.10962],
#        [185.69667],
#        [180.46051],
#        [194.86313],
#        [144.15303]], dtype=float32))
# (250, 'cost:', 2.0309803, '\nPrediction:', array([[150.11446],
#        [185.69334],
#        [180.46198],
#        [194.86441],
#        [144.14847]], dtype=float32))
# (260, 'cost:', 2.0221992, '\nPrediction:', array([[150.11928],
#        [185.69003],
#        [180.46341],
#        [194.86569],
#        [144.1439 ]], dtype=float32))
# (270, 'cost:', 2.0134854, '\nPrediction:', array([[150.12405],
#        [185.6867 ],
#        [180.46484],
#        [194.86694],
#        [144.13934]], dtype=float32))
# (280, 'cost:', 2.0047946, '\nPrediction:', array([[150.12886],
#        [185.6834 ],
#        [180.46628],
#        [194.86824],
#        [144.13483]], dtype=float32))
# (290, 'cost:', 1.996172, '\nPrediction:', array([[150.13364],
#        [185.68011],
#        [180.46771],
#        [194.8695 ],
#        [144.13031]], dtype=float32))
# (300, 'cost:', 1.9875778, '\nPrediction:', array([[150.13838],
#        [185.67682],
#        [180.46915],
#        [194.87077],
#        [144.12578]], dtype=float32))
# (310, 'cost:', 1.979057, '\nPrediction:', array([[150.14313],
#        [185.67352],
#        [180.47057],
#        [194.87201],
#        [144.12129]], dtype=float32))
# (320, 'cost:', 1.9705464, '\nPrediction:', array([[150.14787],
#        [185.67027],
#        [180.472  ],
#        [194.8733 ],
#        [144.1168 ]], dtype=float32))
# (330, 'cost:', 1.962096, '\nPrediction:', array([[150.1526 ],
#        [185.667  ],
#        [180.47342],
#        [194.87456],
#        [144.11234]], dtype=float32))
# (340, 'cost:', 1.9537035, '\nPrediction:', array([[150.15729],
#        [185.66374],
#        [180.47481],
#        [194.8758 ],
#        [144.10786]], dtype=float32))
# (350, 'cost:', 1.9453461, '\nPrediction:', array([[150.16199],
#        [185.6605 ],
#        [180.47621],
#        [194.87703],
#        [144.10341]], dtype=float32))
# (360, 'cost:', 1.9370339, '\nPrediction:', array([[150.16667],
#        [185.65729],
#        [180.47763],
#        [194.87831],
#        [144.09898]], dtype=float32))
# (370, 'cost:', 1.9287598, '\nPrediction:', array([[150.17134],
#        [185.65407],
#        [180.47903],
#        [194.87955],
#        [144.09454]], dtype=float32))
# (380, 'cost:', 1.9205288, '\nPrediction:', array([[150.17601],
#        [185.65083],
#        [180.48044],
#        [194.88081],
#        [144.09015]], dtype=float32))
# (390, 'cost:', 1.912357, '\nPrediction:', array([[150.18063],
#        [185.64763],
#        [180.48181],
#        [194.88202],
#        [144.08572]], dtype=float32))
# (400, 'cost:', 1.904204, '\nPrediction:', array([[150.18527],
#        [185.64444],
#        [180.48322],
#        [194.88329],
#        [144.08133]], dtype=float32))
# (410, 'cost:', 1.896107, '\nPrediction:', array([[150.1899 ],
#        [185.64124],
#        [180.48459],
#        [194.8845 ],
#        [144.07695]], dtype=float32))
# (420, 'cost:', 1.888066, '\nPrediction:', array([[150.1945 ],
#        [185.63806],
#        [180.48598],
#        [194.88573],
#        [144.07259]], dtype=float32))
# (430, 'cost:', 1.880059, '\nPrediction:', array([[150.19908],
#        [185.63489],
#        [180.48735],
#        [194.88696],
#        [144.06822]], dtype=float32))
# (440, 'cost:', 1.8720951, '\nPrediction:', array([[150.20367],
#        [185.63174],
#        [180.48872],
#        [194.8882 ],
#        [144.06389]], dtype=float32))
# (450, 'cost:', 1.8641882, '\nPrediction:', array([[150.20822],
#        [185.62857],
#        [180.49008],
#        [194.8894 ],
#        [144.05956]], dtype=float32))
# (460, 'cost:', 1.8562847, '\nPrediction:', array([[150.2128 ],
#        [185.62543],
#        [180.49146],
#        [194.89062],
#        [144.05522]], dtype=float32))
# (470, 'cost:', 1.8484428, '\nPrediction:', array([[150.21735],
#        [185.6223 ],
#        [180.49281],
#        [194.89186],
#        [144.05092]], dtype=float32))
# (480, 'cost:', 1.8406556, '\nPrediction:', array([[150.22188],
#        [185.61917],
#        [180.49419],
#        [194.89308],
#        [144.04663]], dtype=float32))
# (490, 'cost:', 1.8328981, '\nPrediction:', array([[150.2264 ],
#        [185.61606],
#        [180.49553],
#        [194.89427],
#        [144.04233]], dtype=float32))
# (500, 'cost:', 1.8251804, '\nPrediction:', array([[150.23087],
#        [185.61292],
#        [180.49684],
#        [194.89546],
#        [144.03802]], dtype=float32))
# (510, 'cost:', 1.8175037, '\nPrediction:', array([[150.2354 ],
#        [185.60985],
#        [180.49823],
#        [194.8967 ],
#        [144.03378]], dtype=float32))
# (520, 'cost:', 1.8098625, '\nPrediction:', array([[150.23987],
#        [185.60675],
#        [180.49957],
#        [194.8979 ],
#        [144.02951]], dtype=float32))
# (530, 'cost:', 1.8022915, '\nPrediction:', array([[150.24431],
#        [185.60365],
#        [180.5009 ],
#        [194.8991 ],
#        [144.02527]], dtype=float32))
# (540, 'cost:', 1.7947388, '\nPrediction:', array([[150.24878],
#        [185.60057],
#        [180.50224],
#        [194.90028],
#        [144.02104]], dtype=float32))
# (550, 'cost:', 1.7872212, '\nPrediction:', array([[150.25322],
#        [185.5975 ],
#        [180.50357],
#        [194.90149],
#        [144.01682]], dtype=float32))
# (560, 'cost:', 1.7797394, '\nPrediction:', array([[150.25766],
#        [185.59445],
#        [180.5049 ],
#        [194.9027 ],
#        [144.0126 ]], dtype=float32))
# (570, 'cost:', 1.7723072, '\nPrediction:', array([[150.26208],
#        [185.5914 ],
#        [180.50623],
#        [194.90388],
#        [144.0084 ]], dtype=float32))
# (580, 'cost:', 1.7649431, '\nPrediction:', array([[150.26646],
#        [185.58836],
#        [180.50752],
#        [194.90506],
#        [144.00423]], dtype=float32))
# (590, 'cost:', 1.7575852, '\nPrediction:', array([[150.27086],
#        [185.58531],
#        [180.50885],
#        [194.90622],
#        [144.00003]], dtype=float32))
# (600, 'cost:', 1.7502658, '\nPrediction:', array([[150.27524],
#        [185.58229],
#        [180.51016],
#        [194.90742],
#        [143.99586]], dtype=float32))
# (610, 'cost:', 1.742981, '\nPrediction:', array([[150.27963],
#        [185.57928],
#        [180.51149],
#        [194.90862],
#        [143.99171]], dtype=float32))
# (620, 'cost:', 1.7357657, '\nPrediction:', array([[150.28398],
#        [185.57626],
#        [180.5128 ],
#        [194.90977],
#        [143.98758]], dtype=float32))
# (630, 'cost:', 1.7285618, '\nPrediction:', array([[150.28831],
#        [185.57324],
#        [180.51408],
#        [194.91093],
#        [143.98343]], dtype=float32))
# (640, 'cost:', 1.7214205, '\nPrediction:', array([[150.29265],
#        [185.57027],
#        [180.51538],
#        [194.91211],
#        [143.97932]], dtype=float32))
# (650, 'cost:', 1.7142929, '\nPrediction:', array([[150.29697],
#        [185.56728],
#        [180.51668],
#        [194.91328],
#        [143.9752 ]], dtype=float32))
# (660, 'cost:', 1.70721, '\nPrediction:', array([[150.30128],
#        [185.56432],
#        [180.51797],
#        [194.91444],
#        [143.9711 ]], dtype=float32))
# (670, 'cost:', 1.7001703, '\nPrediction:', array([[150.30559],
#        [185.56134],
#        [180.51927],
#        [194.91562],
#        [143.96703]], dtype=float32))
# (680, 'cost:', 1.6931515, '\nPrediction:', array([[150.30988],
#        [185.55838],
#        [180.52054],
#        [194.91678],
#        [143.96294]], dtype=float32))
# (690, 'cost:', 1.6862007, '\nPrediction:', array([[150.31412],
#        [185.55542],
#        [180.5218 ],
#        [194.91792],
#        [143.95886]], dtype=float32))
# (700, 'cost:', 1.6792343, '\nPrediction:', array([[150.3184 ],
#        [185.55246],
#        [180.52309],
#        [194.91908],
#        [143.95479]], dtype=float32))
# (710, 'cost:', 1.6723562, '\nPrediction:', array([[150.32266],
#        [185.54953],
#        [180.52437],
#        [194.92023],
#        [143.95076]], dtype=float32))
# (720, 'cost:', 1.6654885, '\nPrediction:', array([[150.32689],
#        [185.5466 ],
#        [180.52563],
#        [194.9214 ],
#        [143.94672]], dtype=float32))
# (730, 'cost:', 1.658674, '\nPrediction:', array([[150.33112],
#        [185.5437 ],
#        [180.52689],
#        [194.92253],
#        [143.94269]], dtype=float32))
# (740, 'cost:', 1.6518797, '\nPrediction:', array([[150.33534],
#        [185.54077],
#        [180.52815],
#        [194.92368],
#        [143.93867]], dtype=float32))
# (750, 'cost:', 1.6451304, '\nPrediction:', array([[150.33954],
#        [185.53787],
#        [180.52942],
#        [194.92482],
#        [143.93466]], dtype=float32))
# (760, 'cost:', 1.6384258, '\nPrediction:', array([[150.34373],
#        [185.53497],
#        [180.53067],
#        [194.92595],
#        [143.93068]], dtype=float32))
# (770, 'cost:', 1.6317612, '\nPrediction:', array([[150.34789],
#        [185.53207],
#        [180.5319 ],
#        [194.92706],
#        [143.92668]], dtype=float32))
# (780, 'cost:', 1.6251141, '\nPrediction:', array([[150.35207],
#        [185.52922],
#        [180.53317],
#        [194.92822],
#        [143.92271]], dtype=float32))
# (790, 'cost:', 1.6185033, '\nPrediction:', array([[150.35623],
#        [185.52634],
#        [180.53442],
#        [194.92937],
#        [143.91876]], dtype=float32))
# (800, 'cost:', 1.6119347, '\nPrediction:', array([[150.36037],
#        [185.52347],
#        [180.53564],
#        [194.93047],
#        [143.9148 ]], dtype=float32))
# (810, 'cost:', 1.6053871, '\nPrediction:', array([[150.36452],
#        [185.52063],
#        [180.53688],
#        [194.93161],
#        [143.91086]], dtype=float32))
# (820, 'cost:', 1.5988902, '\nPrediction:', array([[150.36864],
#        [185.51776],
#        [180.53812],
#        [194.93271],
#        [143.90692]], dtype=float32))
# (830, 'cost:', 1.5924221, '\nPrediction:', array([[150.37274],
#        [185.51491],
#        [180.53935],
#        [194.93384],
#        [143.903  ]], dtype=float32))
# (840, 'cost:', 1.5859894, '\nPrediction:', array([[150.37685],
#        [185.51208],
#        [180.54059],
#        [194.93497],
#        [143.8991 ]], dtype=float32))
# (850, 'cost:', 1.5795997, '\nPrediction:', array([[150.38092],
#        [185.50926],
#        [180.5418 ],
#        [194.93607],
#        [143.89519]], dtype=float32))
# (860, 'cost:', 1.5732223, '\nPrediction:', array([[150.38501],
#        [185.50645],
#        [180.54301],
#        [194.9372 ],
#        [143.8913 ]], dtype=float32))
# (870, 'cost:', 1.5668734, '\nPrediction:', array([[150.38907],
#        [185.50362],
#        [180.54422],
#        [194.9383 ],
#        [143.88739]], dtype=float32))
# (880, 'cost:', 1.5605949, '\nPrediction:', array([[150.39311],
#        [185.50084],
#        [180.54544],
#        [194.9394 ],
#        [143.88353]], dtype=float32))
# (890, 'cost:', 1.5543234, '\nPrediction:', array([[150.39717],
#        [185.49805],
#        [180.54665],
#        [194.9405 ],
#        [143.87967]], dtype=float32))
# (900, 'cost:', 1.5480788, '\nPrediction:', array([[150.4012 ],
#        [185.49524],
#        [180.54785],
#        [194.94162],
#        [143.87581]], dtype=float32))
# (910, 'cost:', 1.5418924, '\nPrediction:', array([[150.40523],
#        [185.49246],
#        [180.54906],
#        [194.9427 ],
#        [143.87198]], dtype=float32))
# (920, 'cost:', 1.5357354, '\nPrediction:', array([[150.40923],
#        [185.4897 ],
#        [180.55025],
#        [194.9438 ],
#        [143.86815]], dtype=float32))
# (930, 'cost:', 1.5296093, '\nPrediction:', array([[150.41322],
#        [185.48694],
#        [180.55145],
#        [194.9449 ],
#        [143.86433]], dtype=float32))
# (940, 'cost:', 1.5235058, '\nPrediction:', array([[150.4172 ],
#        [185.48418],
#        [180.55264],
#        [194.946  ],
#        [143.86052]], dtype=float32))
# (950, 'cost:', 1.5174457, '\nPrediction:', array([[150.42119],
#        [185.48145],
#        [180.55385],
#        [194.94708],
#        [143.85672]], dtype=float32))
# (960, 'cost:', 1.5114068, '\nPrediction:', array([[150.42516],
#        [185.47868],
#        [180.55504],
#        [194.94818],
#        [143.85294]], dtype=float32))
# (970, 'cost:', 1.5054057, '\nPrediction:', array([[150.42911],
#        [185.47595],
#        [180.5562 ],
#        [194.94925],
#        [143.84915]], dtype=float32))
# (980, 'cost:', 1.4994463, '\nPrediction:', array([[150.43306],
#        [185.47324],
#        [180.55739],
#        [194.95033],
#        [143.8454 ]], dtype=float32))
# (990, 'cost:', 1.4934849, '\nPrediction:', array([[150.437  ],
#        [185.4705 ],
#        [180.55855],
#        [194.95143],
#        [143.84163]], dtype=float32))
# (1000, 'cost:', 1.487592, '\nPrediction:', array([[150.44092],
#        [185.4678 ],
#        [180.55974],
#        [194.95248],
#        [143.83788]], dtype=float32))
# (1010, 'cost:', 1.4816952, '\nPrediction:', array([[150.44482],
#        [185.46509],
#        [180.5609 ],
#        [194.95358],
#        [143.83412]], dtype=float32))
# (1020, 'cost:', 1.475884, '\nPrediction:', array([[150.4487 ],
#        [185.46239],
#        [180.56206],
#        [194.95462],
#        [143.8304 ]], dtype=float32))
# (1030, 'cost:', 1.4700558, '\nPrediction:', array([[150.4526 ],
#        [185.45972],
#        [180.56322],
#        [194.9557 ],
#        [143.82668]], dtype=float32))
# (1040, 'cost:', 1.464259, '\nPrediction:', array([[150.45648],
#        [185.45702],
#        [180.56436],
#        [194.95677],
#        [143.82295]], dtype=float32))
# (1050, 'cost:', 1.4585127, '\nPrediction:', array([[150.46036],
#        [185.45435],
#        [180.56554],
#        [194.95784],
#        [143.81926]], dtype=float32))
# (1060, 'cost:', 1.4527903, '\nPrediction:', array([[150.46422],
#        [185.45168],
#        [180.56668],
#        [194.9589 ],
#        [143.81557]], dtype=float32))
# (1070, 'cost:', 1.4470956, '\nPrediction:', array([[150.46805],
#        [185.449  ],
#        [180.56783],
#        [194.95996],
#        [143.81187]], dtype=float32))
# (1080, 'cost:', 1.4414451, '\nPrediction:', array([[150.4719 ],
#        [185.44637],
#        [180.56897],
#        [194.96103],
#        [143.80823]], dtype=float32))
# (1090, 'cost:', 1.4358097, '\nPrediction:', array([[150.47572],
#        [185.44374],
#        [180.57013],
#        [194.96208],
#        [143.80455]], dtype=float32))
# (1100, 'cost:', 1.4302127, '\nPrediction:', array([[150.47952],
#        [185.44109],
#        [180.57126],
#        [194.96312],
#        [143.80089]], dtype=float32))
# (1110, 'cost:', 1.4246458, '\nPrediction:', array([[150.48334],
#        [185.43846],
#        [180.5724 ],
#        [194.96417],
#        [143.79726]], dtype=float32))
# (1120, 'cost:', 1.419093, '\nPrediction:', array([[150.48714],
#        [185.43584],
#        [180.57353],
#        [194.96524],
#        [143.79362]], dtype=float32))
# (1130, 'cost:', 1.4135889, '\nPrediction:', array([[150.4909 ],
#        [185.43323],
#        [180.57466],
#        [194.96628],
#        [143.79   ]], dtype=float32))
# (1140, 'cost:', 1.408104, '\nPrediction:', array([[150.49467],
#        [185.4306 ],
#        [180.57578],
#        [194.96732],
#        [143.78638]], dtype=float32))
# (1150, 'cost:', 1.4026532, '\nPrediction:', array([[150.49844],
#        [185.42802],
#        [180.57692],
#        [194.96837],
#        [143.78278]], dtype=float32))
# (1160, 'cost:', 1.3972263, '\nPrediction:', array([[150.5022 ],
#        [185.42542],
#        [180.57803],
#        [194.96939],
#        [143.77917]], dtype=float32))
# (1170, 'cost:', 1.3918121, '\nPrediction:', array([[150.50594],
#        [185.42284],
#        [180.57913],
#        [194.97044],
#        [143.77557]], dtype=float32))
# (1180, 'cost:', 1.3864645, '\nPrediction:', array([[150.50967],
#        [185.42026],
#        [180.58026],
#        [194.97147],
#        [143.77202]], dtype=float32))
# (1190, 'cost:', 1.3811285, '\nPrediction:', array([[150.51338],
#        [185.41768],
#        [180.58138],
#        [194.9725 ],
#        [143.76845]], dtype=float32))
# (1200, 'cost:', 1.3758119, '\nPrediction:', array([[150.51709],
#        [185.41512],
#        [180.58247],
#        [194.97353],
#        [143.76488]], dtype=float32))
# (1210, 'cost:', 1.3705308, '\nPrediction:', array([[150.5208 ],
#        [185.41257],
#        [180.58359],
#        [194.97456],
#        [143.76134]], dtype=float32))
# (1220, 'cost:', 1.3652793, '\nPrediction:', array([[150.52449],
#        [185.41   ],
#        [180.58469],
#        [194.97557],
#        [143.7578 ]], dtype=float32))
# (1230, 'cost:', 1.3600415, '\nPrediction:', array([[150.52815],
#        [185.40746],
#        [180.58577],
#        [194.9766 ],
#        [143.75424]], dtype=float32))
# (1240, 'cost:', 1.3548576, '\nPrediction:', array([[150.53183],
#        [185.40492],
#        [180.58687],
#        [194.97762],
#        [143.75075]], dtype=float32))
# (1250, 'cost:', 1.3496866, '\nPrediction:', array([[150.53548],
#        [185.40239],
#        [180.58795],
#        [194.97862],
#        [143.74722]], dtype=float32))
# (1260, 'cost:', 1.3445364, '\nPrediction:', array([[150.53912],
#        [185.39986],
#        [180.58902],
#        [194.97963],
#        [143.74371]], dtype=float32))
# (1270, 'cost:', 1.3394085, '\nPrediction:', array([[150.54279],
#        [185.39734],
#        [180.59013],
#        [194.98065],
#        [143.74022]], dtype=float32))
# (1280, 'cost:', 1.3343419, '\nPrediction:', array([[150.54639],
#        [185.39484],
#        [180.59122],
#        [194.98166],
#        [143.73674]], dtype=float32))
# (1290, 'cost:', 1.3292716, '\nPrediction:', array([[150.55   ],
#        [185.3923 ],
#        [180.59229],
#        [194.98267],
#        [143.73326]], dtype=float32))
# (1300, 'cost:', 1.3242257, '\nPrediction:', array([[150.55363],
#        [185.38985],
#        [180.59337],
#        [194.98369],
#        [143.7298 ]], dtype=float32))
# (1310, 'cost:', 1.3192184, '\nPrediction:', array([[150.55722],
#        [185.38734],
#        [180.59445],
#        [194.9847 ],
#        [143.72633]], dtype=float32))
# (1320, 'cost:', 1.3142529, '\nPrediction:', array([[150.56079],
#        [185.38484],
#        [180.59552],
#        [194.98567],
#        [143.72289]], dtype=float32))
# (1330, 'cost:', 1.3092867, '\nPrediction:', array([[150.56439],
#        [185.3824 ],
#        [180.59657],
#        [194.98668],
#        [143.71945]], dtype=float32))
# (1340, 'cost:', 1.3043581, '\nPrediction:', array([[150.56796],
#        [185.37993],
#        [180.59766],
#        [194.9877 ],
#        [143.71603]], dtype=float32))
# (1350, 'cost:', 1.2994379, '\nPrediction:', array([[150.57152],
#        [185.37746],
#        [180.5987 ],
#        [194.98868],
#        [143.71259]], dtype=float32))
# (1360, 'cost:', 1.294568, '\nPrediction:', array([[150.57507],
#        [185.37502],
#        [180.59976],
#        [194.98967],
#        [143.70918]], dtype=float32))
# (1370, 'cost:', 1.2897199, '\nPrediction:', array([[150.5786 ],
#        [185.37254],
#        [180.60081],
#        [194.99066],
#        [143.70578]], dtype=float32))
# (1380, 'cost:', 1.2849042, '\nPrediction:', array([[150.5821 ],
#        [185.3701 ],
#        [180.60187],
#        [194.99164],
#        [143.70238]], dtype=float32))
# (1390, 'cost:', 1.2800806, '\nPrediction:', array([[150.58565],
#        [185.36768],
#        [180.6029 ],
#        [194.99265],
#        [143.69899]], dtype=float32))
# (1400, 'cost:', 1.2753133, '\nPrediction:', array([[150.58916],
#        [185.36525],
#        [180.60396],
#        [194.99362],
#        [143.69562]], dtype=float32))
# (1410, 'cost:', 1.2705636, '\nPrediction:', array([[150.59265],
#        [185.36282],
#        [180.605  ],
#        [194.9946 ],
#        [143.69225]], dtype=float32))
# (1420, 'cost:', 1.2658343, '\nPrediction:', array([[150.59615],
#        [185.3604 ],
#        [180.60605],
#        [194.99559],
#        [143.68889]], dtype=float32))
# (1430, 'cost:', 1.2611564, '\nPrediction:', array([[150.59961],
#        [185.35802],
#        [180.60707],
#        [194.99655],
#        [143.68555]], dtype=float32))
# (1440, 'cost:', 1.2564595, '\nPrediction:', array([[150.60309],
#        [185.35559],
#        [180.6081 ],
#        [194.99753],
#        [143.68219]], dtype=float32))
# (1450, 'cost:', 1.2518158, '\nPrediction:', array([[150.60655],
#        [185.3532 ],
#        [180.60915],
#        [194.9985 ],
#        [143.67886]], dtype=float32))
# (1460, 'cost:', 1.2471914, '\nPrediction:', array([[150.61   ],
#        [185.3508 ],
#        [180.61017],
#        [194.99947],
#        [143.67554]], dtype=float32))
# (1470, 'cost:', 1.24259, '\nPrediction:', array([[150.61343],
#        [185.34842],
#        [180.61119],
#        [195.00043],
#        [143.67221]], dtype=float32))
# (1480, 'cost:', 1.238013, '\nPrediction:', array([[150.61687],
#        [185.34605],
#        [180.61221],
#        [195.00139],
#        [143.6689 ]], dtype=float32))
# (1490, 'cost:', 1.2334648, '\nPrediction:', array([[150.62029],
#        [185.34367],
#        [180.61324],
#        [195.00235],
#        [143.6656 ]], dtype=float32))
# (1500, 'cost:', 1.2289305, '\nPrediction:', array([[150.62372],
#        [185.34134],
#        [180.61426],
#        [195.00333],
#        [143.66232]], dtype=float32))
# (1510, 'cost:', 1.2244256, '\nPrediction:', array([[150.6271 ],
#        [185.33897],
#        [180.61526],
#        [195.0043 ],
#        [143.65904]], dtype=float32))
# (1520, 'cost:', 1.2199421, '\nPrediction:', array([[150.63051],
#        [185.33661],
#        [180.61627],
#        [195.00523],
#        [143.65576]], dtype=float32))
# (1530, 'cost:', 1.2154751, '\nPrediction:', array([[150.6339 ],
#        [185.33427],
#        [180.61728],
#        [195.00621],
#        [143.6525 ]], dtype=float32))
# (1540, 'cost:', 1.2110584, '\nPrediction:', array([[150.63727],
#        [185.33195],
#        [180.61829],
#        [195.00714],
#        [143.64925]], dtype=float32))
# (1550, 'cost:', 1.2066395, '\nPrediction:', array([[150.64062],
#        [185.3296 ],
#        [180.6193 ],
#        [195.00812],
#        [143.646  ]], dtype=float32))
# (1560, 'cost:', 1.2022623, '\nPrediction:', array([[150.644  ],
#        [185.3273 ],
#        [180.6203 ],
#        [195.00906],
#        [143.64278]], dtype=float32))
# (1570, 'cost:', 1.1978973, '\nPrediction:', array([[150.64734],
#        [185.32498],
#        [180.62129],
#        [195.01001],
#        [143.63954]], dtype=float32))
# (1580, 'cost:', 1.1935457, '\nPrediction:', array([[150.6507 ],
#        [185.32266],
#        [180.62228],
#        [195.01096],
#        [143.63632]], dtype=float32))
# (1590, 'cost:', 1.1892245, '\nPrediction:', array([[150.654  ],
#        [185.32036],
#        [180.62326],
#        [195.01189],
#        [143.63309]], dtype=float32))
# (1600, 'cost:', 1.1849283, '\nPrediction:', array([[150.65732],
#        [185.31805],
#        [180.62425],
#        [195.01282],
#        [143.62987]], dtype=float32))
# (1610, 'cost:', 1.180668, '\nPrediction:', array([[150.66061],
#        [185.31575],
#        [180.62523],
#        [195.01375],
#        [143.62668]], dtype=float32))
# (1620, 'cost:', 1.1764183, '\nPrediction:', array([[150.66393],
#        [185.31348],
#        [180.6262 ],
#        [195.0147 ],
#        [143.6235 ]], dtype=float32))
# (1630, 'cost:', 1.1721865, '\nPrediction:', array([[150.6672 ],
#        [185.31119],
#        [180.62718],
#        [195.01561],
#        [143.6203 ]], dtype=float32))
# (1640, 'cost:', 1.167987, '\nPrediction:', array([[150.6705 ],
#        [185.30893],
#        [180.62817],
#        [195.01657],
#        [143.61716]], dtype=float32))
# (1650, 'cost:', 1.1638048, '\nPrediction:', array([[150.67378],
#        [185.30667],
#        [180.62917],
#        [195.01749],
#        [143.61398]], dtype=float32))
# (1660, 'cost:', 1.159642, '\nPrediction:', array([[150.67703],
#        [185.3044 ],
#        [180.63013],
#        [195.01845],
#        [143.61084]], dtype=float32))
# (1670, 'cost:', 1.155498, '\nPrediction:', array([[150.6803 ],
#        [185.30215],
#        [180.6311 ],
#        [195.01936],
#        [143.60768]], dtype=float32))
# (1680, 'cost:', 1.1513851, '\nPrediction:', array([[150.68353],
#        [185.2999 ],
#        [180.63206],
#        [195.02028],
#        [143.60454]], dtype=float32))
# (1690, 'cost:', 1.1472827, '\nPrediction:', array([[150.68678],
#        [185.29765],
#        [180.63301],
#        [195.0212 ],
#        [143.60141]], dtype=float32))
# (1700, 'cost:', 1.1432087, '\nPrediction:', array([[150.69   ],
#        [185.29544],
#        [180.63397],
#        [195.02213],
#        [143.59828]], dtype=float32))
# (1710, 'cost:', 1.1391541, '\nPrediction:', array([[150.69322],
#        [185.29318],
#        [180.63492],
#        [195.02301],
#        [143.59515]], dtype=float32))
# (1720, 'cost:', 1.1351289, '\nPrediction:', array([[150.69643],
#        [185.29097],
#        [180.63588],
#        [195.02394],
#        [143.59206]], dtype=float32))
# (1730, 'cost:', 1.1311105, '\nPrediction:', array([[150.69963],
#        [185.28876],
#        [180.63683],
#        [195.02487],
#        [143.58896]], dtype=float32))
# (1740, 'cost:', 1.1271282, '\nPrediction:', array([[150.70284],
#        [185.28654],
#        [180.63779],
#        [195.02577],
#        [143.58588]], dtype=float32))
# (1750, 'cost:', 1.123164, '\nPrediction:', array([[150.70601],
#        [185.28435],
#        [180.63873],
#        [195.02669],
#        [143.5828 ]], dtype=float32))
# (1760, 'cost:', 1.1192125, '\nPrediction:', array([[150.70918],
#        [185.28215],
#        [180.63966],
#        [195.02759],
#        [143.57971]], dtype=float32))
# (1770, 'cost:', 1.1152885, '\nPrediction:', array([[150.71236],
#        [185.27995],
#        [180.64061],
#        [195.0285 ],
#        [143.57666]], dtype=float32))
# (1780, 'cost:', 1.1113926, '\nPrediction:', array([[150.7155 ],
#        [185.27777],
#        [180.64157],
#        [195.0294 ],
#        [143.5736 ]], dtype=float32))
# (1790, 'cost:', 1.1074995, '\nPrediction:', array([[150.71864],
#        [185.27557],
#        [180.64249],
#        [195.03029],
#        [143.57053]], dtype=float32))
# (1800, 'cost:', 1.1036432, '\nPrediction:', array([[150.72177],
#        [185.27339],
#        [180.64342],
#        [195.03119],
#        [143.56749]], dtype=float32))
# (1810, 'cost:', 1.099791, '\nPrediction:', array([[150.72491],
#        [185.27122],
#        [180.64435],
#        [195.03209],
#        [143.56445]], dtype=float32))
# (1820, 'cost:', 1.0959755, '\nPrediction:', array([[150.72804],
#        [185.26909],
#        [180.64528],
#        [195.03297],
#        [143.56143]], dtype=float32))
# (1830, 'cost:', 1.0921705, '\nPrediction:', array([[150.73114],
#        [185.26692],
#        [180.64621],
#        [195.03389],
#        [143.55841]], dtype=float32))
# (1840, 'cost:', 1.0883902, '\nPrediction:', array([[150.73425],
#        [185.26477],
#        [180.64713],
#        [195.03479],
#        [143.55542]], dtype=float32))
# (1850, 'cost:', 1.0846313, '\nPrediction:', array([[150.73735],
#        [185.26265],
#        [180.64806],
#        [195.03568],
#        [143.55241]], dtype=float32))
# (1860, 'cost:', 1.0808828, '\nPrediction:', array([[150.74043],
#        [185.2605 ],
#        [180.64897],
#        [195.03656],
#        [143.54941]], dtype=float32))
# (1870, 'cost:', 1.0771458, '\nPrediction:', array([[150.74352],
#        [185.25835],
#        [180.64986],
#        [195.03745],
#        [143.54642]], dtype=float32))
# (1880, 'cost:', 1.0734452, '\nPrediction:', array([[150.74658],
#        [185.25621],
#        [180.65077],
#        [195.03833],
#        [143.54344]], dtype=float32))
# (1890, 'cost:', 1.0697651, '\nPrediction:', array([[150.74963],
#        [185.2541 ],
#        [180.65169],
#        [195.03922],
#        [143.54047]], dtype=float32))
# (1900, 'cost:', 1.0661042, '\nPrediction:', array([[150.75272],
#        [185.252  ],
#        [180.6526 ],
#        [195.04008],
#        [143.53752]], dtype=float32))
# (1910, 'cost:', 1.0624564, '\nPrediction:', array([[150.75575],
#        [185.2499 ],
#        [180.6535 ],
#        [195.04097],
#        [143.53456]], dtype=float32))
# (1920, 'cost:', 1.058828, '\nPrediction:', array([[150.75879],
#        [185.24779],
#        [180.65442],
#        [195.04184],
#        [143.5316 ]], dtype=float32))
# (1930, 'cost:', 1.0552182, '\nPrediction:', array([[150.76181],
#        [185.24568],
#        [180.6553 ],
#        [195.04271],
#        [143.52866]], dtype=float32))
# (1940, 'cost:', 1.0516348, '\nPrediction:', array([[150.76482],
#        [185.24358],
#        [180.65619],
#        [195.04358],
#        [143.52573]], dtype=float32))
# (1950, 'cost:', 1.0480648, '\nPrediction:', array([[150.76782],
#        [185.24147],
#        [180.65709],
#        [195.04445],
#        [143.5228 ]], dtype=float32))
# (1960, 'cost:', 1.0445207, '\nPrediction:', array([[150.77083],
#        [185.23944],
#        [180.65799],
#        [195.04532],
#        [143.51988]], dtype=float32))
# (1970, 'cost:', 1.040993, '\nPrediction:', array([[150.77382],
#        [185.23735],
#        [180.65887],
#        [195.04619],
#        [143.51698]], dtype=float32))
# (1980, 'cost:', 1.0374682, '\nPrediction:', array([[150.77681],
#        [185.23529],
#        [180.65976],
#        [195.04706],
#        [143.51407]], dtype=float32))
# (1990, 'cost:', 1.033974, '\nPrediction:', array([[150.77979],
#        [185.2332 ],
#        [180.66063],
#        [195.0479 ],
#        [143.51117]], dtype=float32))
# (2000, 'cost:', 1.030501, '\nPrediction:', array([[150.78275],
#        [185.23114],
#        [180.66151],
#        [195.04877],
#        [143.50829]], dtype=float32))
