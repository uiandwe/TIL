# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint,EarlyStopping

import pandas as pd
import numpy
import os
import tensorflow as tf

# seed 값 설정
seed = 0
numpy.random.seed(seed)
tf.set_random_seed(seed)

df_pre = pd.read_csv('wine.csv', header=None)
df = df_pre.sample(frac=0.15)

dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])

# 모델 저장 폴더 만들기
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"

# 모델 업데이트 및 저장
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# 학습 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

model.fit(X, Y, validation_split=0.2, epochs=3500, batch_size=500, verbose=0, callbacks=[early_stopping_callback,checkpointer])
# Out:
# Epoch 00001: val_loss improved from inf to 0.48570, saving model to ./model/01-0.4857.hdf5
#
# Epoch 00002: val_loss improved from 0.48570 to 0.45984, saving model to ./model/02-0.4598.hdf5
#
# Epoch 00003: val_loss improved from 0.45984 to 0.43358, saving model to ./model/03-0.4336.hdf5
#
# Epoch 00004: val_loss improved from 0.43358 to 0.42008, saving model to ./model/04-0.4201.hdf5
#
# Epoch 00005: val_loss improved from 0.42008 to 0.40731, saving model to ./model/05-0.4073.hdf5
#
# Epoch 00006: val_loss improved from 0.40731 to 0.39417, saving model to ./model/06-0.3942.hdf5
#
# Epoch 00007: val_loss improved from 0.39417 to 0.38610, saving model to ./model/07-0.3861.hdf5
#
# Epoch 00008: val_loss improved from 0.38610 to 0.37907, saving model to ./model/08-0.3791.hdf5
#
# Epoch 00009: val_loss improved from 0.37907 to 0.37236, saving model to ./model/09-0.3724.hdf5
#
# Epoch 00010: val_loss improved from 0.37236 to 0.36545, saving model to ./model/10-0.3654.hdf5
#
# Epoch 00011: val_loss improved from 0.36545 to 0.35937, saving model to ./model/11-0.3594.hdf5
#
# Epoch 00012: val_loss improved from 0.35937 to 0.35421, saving model to ./model/12-0.3542.hdf5
#
# Epoch 00013: val_loss improved from 0.35421 to 0.34949, saving model to ./model/13-0.3495.hdf5
#
# Epoch 00014: val_loss improved from 0.34949 to 0.34465, saving model to ./model/14-0.3446.hdf5
#
# Epoch 00015: val_loss improved from 0.34465 to 0.33867, saving model to ./model/15-0.3387.hdf5
#
# Epoch 00016: val_loss improved from 0.33867 to 0.33332, saving model to ./model/16-0.3333.hdf5
#
# Epoch 00017: val_loss improved from 0.33332 to 0.32866, saving model to ./model/17-0.3287.hdf5
#
# Epoch 00018: val_loss improved from 0.32866 to 0.32492, saving model to ./model/18-0.3249.hdf5
#
# Epoch 00019: val_loss improved from 0.32492 to 0.32350, saving model to ./model/19-0.3235.hdf5
#
# Epoch 00020: val_loss improved from 0.32350 to 0.31969, saving model to ./model/20-0.3197.hdf5
#
# Epoch 00021: val_loss improved from 0.31969 to 0.31238, saving model to ./model/21-0.3124.hdf5
#
# Epoch 00022: val_loss improved from 0.31238 to 0.30762, saving model to ./model/22-0.3076.hdf5
#
# Epoch 00023: val_loss improved from 0.30762 to 0.30344, saving model to ./model/23-0.3034.hdf5
#
# Epoch 00024: val_loss improved from 0.30344 to 0.30024, saving model to ./model/24-0.3002.hdf5
#
# Epoch 00025: val_loss improved from 0.30024 to 0.29844, saving model to ./model/25-0.2984.hdf5
#
# Epoch 00026: val_loss improved from 0.29844 to 0.29365, saving model to ./model/26-0.2937.hdf5
#
# Epoch 00027: val_loss improved from 0.29365 to 0.28760, saving model to ./model/27-0.2876.hdf5
#
# Epoch 00028: val_loss improved from 0.28760 to 0.28375, saving model to ./model/28-0.2838.hdf5
#
# Epoch 00029: val_loss improved from 0.28375 to 0.27915, saving model to ./model/29-0.2791.hdf5
#
# Epoch 00030: val_loss improved from 0.27915 to 0.27652, saving model to ./model/30-0.2765.hdf5
#
# Epoch 00031: val_loss improved from 0.27652 to 0.27253, saving model to ./model/31-0.2725.hdf5
#
# Epoch 00032: val_loss improved from 0.27253 to 0.26758, saving model to ./model/32-0.2676.hdf5
#
# Epoch 00033: val_loss improved from 0.26758 to 0.26388, saving model to ./model/33-0.2639.hdf5
#
# Epoch 00034: val_loss improved from 0.26388 to 0.26048, saving model to ./model/34-0.2605.hdf5
#
# Epoch 00035: val_loss improved from 0.26048 to 0.25876, saving model to ./model/35-0.2588.hdf5
#
# Epoch 00036: val_loss improved from 0.25876 to 0.25565, saving model to ./model/36-0.2557.hdf5
#
# Epoch 00037: val_loss improved from 0.25565 to 0.25238, saving model to ./model/37-0.2524.hdf5
#
# Epoch 00038: val_loss improved from 0.25238 to 0.24974, saving model to ./model/38-0.2497.hdf5
#
# Epoch 00039: val_loss improved from 0.24974 to 0.24756, saving model to ./model/39-0.2476.hdf5
#
# Epoch 00040: val_loss improved from 0.24756 to 0.24561, saving model to ./model/40-0.2456.hdf5
#
# Epoch 00041: val_loss improved from 0.24561 to 0.24465, saving model to ./model/41-0.2446.hdf5
#
# Epoch 00042: val_loss improved from 0.24465 to 0.24249, saving model to ./model/42-0.2425.hdf5
#
# Epoch 00043: val_loss improved from 0.24249 to 0.24059, saving model to ./model/43-0.2406.hdf5
#
# Epoch 00044: val_loss improved from 0.24059 to 0.23856, saving model to ./model/44-0.2386.hdf5
#
# Epoch 00045: val_loss improved from 0.23856 to 0.23775, saving model to ./model/45-0.2378.hdf5
#
# Epoch 00046: val_loss improved from 0.23775 to 0.23758, saving model to ./model/46-0.2376.hdf5
#
# Epoch 00047: val_loss improved from 0.23758 to 0.23512, saving model to ./model/47-0.2351.hdf5
#
# Epoch 00048: val_loss improved from 0.23512 to 0.23234, saving model to ./model/48-0.2323.hdf5
#
# Epoch 00049: val_loss improved from 0.23234 to 0.23065, saving model to ./model/49-0.2307.hdf5
#
# Epoch 00050: val_loss improved from 0.23065 to 0.22978, saving model to ./model/50-0.2298.hdf5
#
# Epoch 00051: val_loss improved from 0.22978 to 0.22797, saving model to ./model/51-0.2280.hdf5
#
# Epoch 00052: val_loss improved from 0.22797 to 0.22670, saving model to ./model/52-0.2267.hdf5
#
# Epoch 00053: val_loss improved from 0.22670 to 0.22517, saving model to ./model/53-0.2252.hdf5
#
# Epoch 00054: val_loss improved from 0.22517 to 0.22423, saving model to ./model/54-0.2242.hdf5
#
# Epoch 00055: val_loss improved from 0.22423 to 0.22289, saving model to ./model/55-0.2229.hdf5
#
# Epoch 00056: val_loss improved from 0.22289 to 0.22090, saving model to ./model/56-0.2209.hdf5
#
# Epoch 00057: val_loss improved from 0.22090 to 0.21925, saving model to ./model/57-0.2192.hdf5
#
# Epoch 00058: val_loss improved from 0.21925 to 0.21754, saving model to ./model/58-0.2175.hdf5
#
# Epoch 00059: val_loss improved from 0.21754 to 0.21581, saving model to ./model/59-0.2158.hdf5
#
# Epoch 00060: val_loss improved from 0.21581 to 0.21506, saving model to ./model/60-0.2151.hdf5
#
# Epoch 00061: val_loss improved from 0.21506 to 0.21490, saving model to ./model/61-0.2149.hdf5
#
# Epoch 00062: val_loss improved from 0.21490 to 0.21172, saving model to ./model/62-0.2117.hdf5
#
# Epoch 00063: val_loss improved from 0.21172 to 0.20947, saving model to ./model/63-0.2095.hdf5
#
# Epoch 00064: val_loss improved from 0.20947 to 0.20825, saving model to ./model/64-0.2082.hdf5
#
# Epoch 00065: val_loss improved from 0.20825 to 0.20815, saving model to ./model/65-0.2081.hdf5
#
# Epoch 00066: val_loss improved from 0.20815 to 0.20757, saving model to ./model/66-0.2076.hdf5
#
# Epoch 00067: val_loss improved from 0.20757 to 0.20507, saving model to ./model/67-0.2051.hdf5
#
# Epoch 00068: val_loss improved from 0.20507 to 0.20428, saving model to ./model/68-0.2043.hdf5
#
# Epoch 00069: val_loss improved from 0.20428 to 0.20293, saving model to ./model/69-0.2029.hdf5
#
# Epoch 00070: val_loss improved from 0.20293 to 0.20286, saving model to ./model/70-0.2029.hdf5
#
# Epoch 00071: val_loss did not improve from 0.20286
#
# Epoch 00072: val_loss improved from 0.20286 to 0.20141, saving model to ./model/72-0.2014.hdf5
#
# Epoch 00073: val_loss improved from 0.20141 to 0.19842, saving model to ./model/73-0.1984.hdf5
#
# Epoch 00074: val_loss improved from 0.19842 to 0.19729, saving model to ./model/74-0.1973.hdf5
#
# Epoch 00075: val_loss improved from 0.19729 to 0.19727, saving model to ./model/75-0.1973.hdf5
#
# Epoch 00076: val_loss did not improve from 0.19727
#
# Epoch 00077: val_loss improved from 0.19727 to 0.19700, saving model to ./model/77-0.1970.hdf5
#
# Epoch 00078: val_loss improved from 0.19700 to 0.19531, saving model to ./model/78-0.1953.hdf5
#
# Epoch 00079: val_loss improved from 0.19531 to 0.19241, saving model to ./model/79-0.1924.hdf5
#
# Epoch 00080: val_loss improved from 0.19241 to 0.19111, saving model to ./model/80-0.1911.hdf5
#
# Epoch 00081: val_loss did not improve from 0.19111
#
# Epoch 00082: val_loss did not improve from 0.19111
#
# Epoch 00083: val_loss did not improve from 0.19111
#
# Epoch 00084: val_loss improved from 0.19111 to 0.18830, saving model to ./model/84-0.1883.hdf5
#
# Epoch 00085: val_loss improved from 0.18830 to 0.18740, saving model to ./model/85-0.1874.hdf5
#
# Epoch 00086: val_loss improved from 0.18740 to 0.18713, saving model to ./model/86-0.1871.hdf5
#
# Epoch 00087: val_loss did not improve from 0.18713
#
# Epoch 00088: val_loss did not improve from 0.18713
#
# Epoch 00089: val_loss improved from 0.18713 to 0.18651, saving model to ./model/89-0.1865.hdf5
#
# Epoch 00090: val_loss improved from 0.18651 to 0.18383, saving model to ./model/90-0.1838.hdf5
#
# Epoch 00091: val_loss improved from 0.18383 to 0.18250, saving model to ./model/91-0.1825.hdf5
#
# Epoch 00092: val_loss did not improve from 0.18250
#
# Epoch 00093: val_loss did not improve from 0.18250
#
# Epoch 00094: val_loss did not improve from 0.18250
#
# Epoch 00095: val_loss improved from 0.18250 to 0.18162, saving model to ./model/95-0.1816.hdf5
#
# Epoch 00096: val_loss improved from 0.18162 to 0.18065, saving model to ./model/96-0.1807.hdf5
#
# Epoch 00097: val_loss improved from 0.18065 to 0.18021, saving model to ./model/97-0.1802.hdf5
#
# Epoch 00098: val_loss improved from 0.18021 to 0.17933, saving model to ./model/98-0.1793.hdf5
# Epoch 00099: val_loss improved from 0.17933 to 0.17913, saving model to ./model/99-0.1791.hdf5
#
# Epoch 00100: val_loss improved from 0.17913 to 0.17750, saving model to ./model/100-0.1775.hdf5
#
# Epoch 00101: val_loss improved from 0.17750 to 0.17608, saving model to ./model/101-0.1761.hdf5
#
# Epoch 00102: val_loss improved from 0.17608 to 0.17433, saving model to ./model/102-0.1743.hdf5
#
# Epoch 00103: val_loss improved from 0.17433 to 0.17370, saving model to ./model/103-0.1737.hdf5
#
# Epoch 00104: val_loss did not improve from 0.17370
#
# Epoch 00105: val_loss did not improve from 0.17370
#
# Epoch 00106: val_loss did not improve from 0.17370
#
# Epoch 00107: val_loss improved from 0.17370 to 0.17022, saving model to ./model/107-0.1702.hdf5
#
# Epoch 00108: val_loss improved from 0.17022 to 0.16946, saving model to ./model/108-0.1695.hdf5
#
# Epoch 00109: val_loss did not improve from 0.16946
#
# Epoch 00110: val_loss did not improve from 0.16946
#
# Epoch 00111: val_loss did not improve from 0.16946
#
# Epoch 00112: val_loss improved from 0.16946 to 0.16685, saving model to ./model/112-0.1668.hdf5
#
# Epoch 00113: val_loss improved from 0.16685 to 0.16624, saving model to ./model/113-0.1662.hdf5
#
# Epoch 00114: val_loss did not improve from 0.16624
#
# Epoch 00115: val_loss did not improve from 0.16624
#
# Epoch 00116: val_loss did not improve from 0.16624
#
# Epoch 00117: val_loss improved from 0.16624 to 0.16483, saving model to ./model/117-0.1648.hdf5
#
# Epoch 00118: val_loss improved from 0.16483 to 0.16437, saving model to ./model/118-0.1644.hdf5
#
# Epoch 00119: val_loss did not improve from 0.16437
#
# Epoch 00120: val_loss did not improve from 0.16437
#
# Epoch 00121: val_loss improved from 0.16437 to 0.16401, saving model to ./model/121-0.1640.hdf5
#
# Epoch 00122: val_loss improved from 0.16401 to 0.16036, saving model to ./model/122-0.1604.hdf5
#
# Epoch 00123: val_loss did not improve from 0.16036
#
# Epoch 00124: val_loss did not improve from 0.16036
#
# Epoch 00125: val_loss did not improve from 0.16036
#
# Epoch 00126: val_loss did not improve from 0.16036
#
# Epoch 00127: val_loss improved from 0.16036 to 0.15828, saving model to ./model/127-0.1583.hdf5
#
# Epoch 00128: val_loss did not improve from 0.15828
#
# Epoch 00129: val_loss did not improve from 0.15828
#
# Epoch 00130: val_loss did not improve from 0.15828
#
# Epoch 00131: val_loss did not improve from 0.15828
#
# Epoch 00132: val_loss improved from 0.15828 to 0.15616, saving model to ./model/132-0.1562.hdf5
#
# Epoch 00133: val_loss improved from 0.15616 to 0.15540, saving model to ./model/133-0.1554.hdf5
#
# Epoch 00134: val_loss did not improve from 0.15540
#
# Epoch 00135: val_loss did not improve from 0.15540
#
# Epoch 00136: val_loss improved from 0.15540 to 0.15452, saving model to ./model/136-0.1545.hdf5
#
# Epoch 00137: val_loss improved from 0.15452 to 0.15356, saving model to ./model/137-0.1536.hdf5
#
# Epoch 00138: val_loss did not improve from 0.15356
#
# Epoch 00139: val_loss did not improve from 0.15356
#
# Epoch 00140: val_loss improved from 0.15356 to 0.15243, saving model to ./model/140-0.1524.hdf5
#
# Epoch 00141: val_loss improved from 0.15243 to 0.15137, saving model to ./model/141-0.1514.hdf5
#
# Epoch 00142: val_loss did not improve from 0.15137
#
# Epoch 00143: val_loss did not improve from 0.15137
#
# Epoch 00144: val_loss did not improve from 0.15137
#
# Epoch 00145: val_loss improved from 0.15137 to 0.14917, saving model to ./model/145-0.1492.hdf5
#
# Epoch 00146: val_loss improved from 0.14917 to 0.14879, saving model to ./model/146-0.1488.hdf5
#
# Epoch 00147: val_loss did not improve from 0.14879
#
# Epoch 00148: val_loss did not improve from 0.14879
#
# Epoch 00149: val_loss did not improve from 0.14879
#
# Epoch 00150: val_loss did not improve from 0.14879
#
# Epoch 00151: val_loss did not improve from 0.14879
#
# Epoch 00152: val_loss did not improve from 0.14879
#
# Epoch 00153: val_loss did not improve from 0.14879
#
# Epoch 00154: val_loss improved from 0.14879 to 0.14604, saving model to ./model/154-0.1460.hdf5
#
# Epoch 00155: val_loss improved from 0.14604 to 0.14423, saving model to ./model/155-0.1442.hdf5
#
# Epoch 00156: val_loss did not improve from 0.14423
#
# Epoch 00157: val_loss did not improve from 0.14423
#
# Epoch 00158: val_loss did not improve from 0.14423
#
# Epoch 00159: val_loss did not improve from 0.14423
#
# Epoch 00160: val_loss improved from 0.14423 to 0.14337, saving model to ./model/160-0.1434.hdf5
#
# Epoch 00161: val_loss did not improve from 0.14337
#
# Epoch 00162: val_loss did not improve from 0.14337
#
# Epoch 00163: val_loss improved from 0.14337 to 0.14270, saving model to ./model/163-0.1427.hdf5
#
# Epoch 00164: val_loss improved from 0.14270 to 0.14074, saving model to ./model/164-0.1407.hdf5
#
# Epoch 00165: val_loss did not improve from 0.14074
#
# Epoch 00166: val_loss did not improve from 0.14074
#
# Epoch 00167: val_loss did not improve from 0.14074
#
# Epoch 00168: val_loss improved from 0.14074 to 0.13941, saving model to ./model/168-0.1394.hdf5
#
# Epoch 00169: val_loss improved from 0.13941 to 0.13845, saving model to ./model/169-0.1384.hdf5
#
# Epoch 00170: val_loss did not improve from 0.13845
#
# Epoch 00171: val_loss did not improve from 0.13845
#
# Epoch 00172: val_loss did not improve from 0.13845
#
# Epoch 00173: val_loss did not improve from 0.13845
#
# Epoch 00174: val_loss did not improve from 0.13845
#
# Epoch 00175: val_loss did not improve from 0.13845
#
# Epoch 00176: val_loss improved from 0.13845 to 0.13552, saving model to ./model/176-0.1355.hdf5
#
# Epoch 00177: val_loss did not improve from 0.13552
#
# Epoch 00178: val_loss did not improve from 0.13552
#
# Epoch 00179: val_loss did not improve from 0.13552
#
# Epoch 00180: val_loss did not improve from 0.13552
#
# Epoch 00181: val_loss improved from 0.13552 to 0.13351, saving model to ./model/181-0.1335.hdf5
#
# Epoch 00182: val_loss did not improve from 0.13351
#
# Epoch 00183: val_loss did not improve from 0.13351
#
# Epoch 00184: val_loss did not improve from 0.13351
#
# Epoch 00185: val_loss did not improve from 0.13351
#
# Epoch 00186: val_loss improved from 0.13351 to 0.13270, saving model to ./model/186-0.1327.hdf5
#
# Epoch 00187: val_loss did not improve from 0.13270
#
# Epoch 00188: val_loss did not improve from 0.13270
#
# Epoch 00189: val_loss did not improve from 0.13270
#
# Epoch 00190: val_loss improved from 0.13270 to 0.13046, saving model to ./model/190-0.1305.hdf5
#
# Epoch 00191: val_loss did not improve from 0.13046
#
# Epoch 00192: val_loss did not improve from 0.13046
#
# Epoch 00193: val_loss did not improve from 0.13046
#
# Epoch 00194: val_loss improved from 0.13046 to 0.13006, saving model to ./model/194-0.1301.hdf5
#
# Epoch 00195: val_loss did not improve from 0.13006
#
# Epoch 00196: val_loss did not improve from 0.13006
#
# Epoch 00197: val_loss improved from 0.13006 to 0.12972, saving model to ./model/197-0.1297.hdf5
#
# Epoch 00198: val_loss improved from 0.12972 to 0.12755, saving model to ./model/198-0.1276.hdf5
#
# Epoch 00199: val_loss did not improve from 0.12755
#
# Epoch 00200: val_loss did not improve from 0.12755
#
# Epoch 00201: val_loss did not improve from 0.12755
#
# Epoch 00202: val_loss improved from 0.12755 to 0.12663, saving model to ./model/202-0.1266.hdf5
#
# Epoch 00203: val_loss did not improve from 0.12663
#
# Epoch 00204: val_loss did not improve from 0.12663
#
# Epoch 00205: val_loss did not improve from 0.12663
#
# Epoch 00206: val_loss improved from 0.12663 to 0.12588, saving model to ./model/206-0.1259.hdf5
#
# Epoch 00207: val_loss did not improve from 0.12588
#
# Epoch 00208: val_loss did not improve from 0.12588
#
# Epoch 00209: val_loss did not improve from 0.12588
#
# Epoch 00210: val_loss did not improve from 0.12588
#
# Epoch 00211: val_loss improved from 0.12588 to 0.12503, saving model to ./model/211-0.1250.hdf5
#
# Epoch 00212: val_loss did not improve from 0.12503
#
# Epoch 00213: val_loss did not improve from 0.12503
#
# Epoch 00214: val_loss did not improve from 0.12503
#
# Epoch 00215: val_loss improved from 0.12503 to 0.12373, saving model to ./model/215-0.1237.hdf5
#
# Epoch 00216: val_loss did not improve from 0.12373
#
# Epoch 00217: val_loss did not improve from 0.12373
#
# Epoch 00218: val_loss did not improve from 0.12373
#
# Epoch 00219: val_loss did not improve from 0.12373
#
# Epoch 00220: val_loss did not improve from 0.12373
#
# Epoch 00221: val_loss did not improve from 0.12373
#
# Epoch 00222: val_loss did not improve from 0.12373
#
# Epoch 00223: val_loss did not improve from 0.12373
#
# Epoch 00224: val_loss did not improve from 0.12373
#
# Epoch 00225: val_loss did not improve from 0.12373
#
# Epoch 00226: val_loss did not improve from 0.12373
#
# Epoch 00227: val_loss improved from 0.12373 to 0.12208, saving model to ./model/227-0.1221.hdf5
#
# Epoch 00228: val_loss did not improve from 0.12208
#
# Epoch 00229: val_loss did not improve from 0.12208
#
# Epoch 00230: val_loss improved from 0.12208 to 0.12090, saving model to ./model/230-0.1209.hdf5
#
# Epoch 00231: val_loss improved from 0.12090 to 0.11954, saving model to ./model/231-0.1195.hdf5
#
# Epoch 00232: val_loss did not improve from 0.11954
#
# Epoch 00233: val_loss did not improve from 0.11954
#
# Epoch 00234: val_loss improved from 0.11954 to 0.11874, saving model to ./model/234-0.1187.hdf5
#
# Epoch 00235: val_loss did not improve from 0.11874
#
# Epoch 00236: val_loss did not improve from 0.11874
#
# Epoch 00237: val_loss did not improve from 0.11874
#
# Epoch 00238: val_loss improved from 0.11874 to 0.11801, saving model to ./model/238-0.1180.hdf5
#
# Epoch 00239: val_loss did not improve from 0.11801
#
# Epoch 00240: val_loss did not improve from 0.11801
#
# Epoch 00241: val_loss did not improve from 0.11801
#
# Epoch 00242: val_loss improved from 0.11801 to 0.11569, saving model to ./model/242-0.1157.hdf5
# Epoch 00243: val_loss did not improve from 0.11569
#
# Epoch 00244: val_loss did not improve from 0.11569
#
# Epoch 00245: val_loss did not improve from 0.11569
#
# Epoch 00246: val_loss did not improve from 0.11569
#
# Epoch 00247: val_loss did not improve from 0.11569
#
# Epoch 00248: val_loss did not improve from 0.11569
#
# Epoch 00249: val_loss did not improve from 0.11569
#
# Epoch 00250: val_loss improved from 0.11569 to 0.11361, saving model to ./model/250-0.1136.hdf5
#
# Epoch 00251: val_loss did not improve from 0.11361
#
# Epoch 00252: val_loss did not improve from 0.11361
#
# Epoch 00253: val_loss did not improve from 0.11361
#
# Epoch 00254: val_loss improved from 0.11361 to 0.11326, saving model to ./model/254-0.1133.hdf5
#
# Epoch 00255: val_loss did not improve from 0.11326
#
# Epoch 00256: val_loss did not improve from 0.11326
#
# Epoch 00257: val_loss did not improve from 0.11326
#
# Epoch 00258: val_loss improved from 0.11326 to 0.11272, saving model to ./model/258-0.1127.hdf5
#
# Epoch 00259: val_loss did not improve from 0.11272
#
# Epoch 00260: val_loss did not improve from 0.11272
#
# Epoch 00261: val_loss improved from 0.11272 to 0.11242, saving model to ./model/261-0.1124.hdf5
#
# Epoch 00262: val_loss improved from 0.11242 to 0.11163, saving model to ./model/262-0.1116.hdf5
#
# Epoch 00263: val_loss did not improve from 0.11163
#
# Epoch 00264: val_loss did not improve from 0.11163
#
# Epoch 00265: val_loss did not improve from 0.11163
#
# Epoch 00266: val_loss improved from 0.11163 to 0.10858, saving model to ./model/266-0.1086.hdf5
#
# Epoch 00267: val_loss did not improve from 0.10858
#
# Epoch 00268: val_loss did not improve from 0.10858
#
# Epoch 00269: val_loss did not improve from 0.10858
#
# Epoch 00270: val_loss did not improve from 0.10858
#
# Epoch 00271: val_loss did not improve from 0.10858
#
# Epoch 00272: val_loss did not improve from 0.10858
#
# Epoch 00273: val_loss did not improve from 0.10858
#
# Epoch 00274: val_loss did not improve from 0.10858
#
# Epoch 00275: val_loss did not improve from 0.10858
#
# Epoch 00276: val_loss did not improve from 0.10858
#
# Epoch 00277: val_loss did not improve from 0.10858
#
# Epoch 00278: val_loss did not improve from 0.10858
#
# Epoch 00279: val_loss improved from 0.10858 to 0.10827, saving model to ./model/279-0.1083.hdf5
#
# Epoch 00280: val_loss did not improve from 0.10827
#
# Epoch 00281: val_loss did not improve from 0.10827
#
# Epoch 00282: val_loss did not improve from 0.10827
#
# Epoch 00283: val_loss did not improve from 0.10827
#
# Epoch 00284: val_loss did not improve from 0.10827
#
# Epoch 00285: val_loss did not improve from 0.10827
#
# Epoch 00286: val_loss did not improve from 0.10827
#
# Epoch 00287: val_loss improved from 0.10827 to 0.10630, saving model to ./model/287-0.1063.hdf5
#
# Epoch 00288: val_loss did not improve from 0.10630
#
# Epoch 00289: val_loss did not improve from 0.10630
#
# Epoch 00290: val_loss did not improve from 0.10630
#
# Epoch 00291: val_loss did not improve from 0.10630
#
# Epoch 00292: val_loss improved from 0.10630 to 0.10434, saving model to ./model/292-0.1043.hdf5
#
# Epoch 00293: val_loss did not improve from 0.10434
#
# Epoch 00294: val_loss did not improve from 0.10434
#
# Epoch 00295: val_loss did not improve from 0.10434
#
# Epoch 00296: val_loss did not improve from 0.10434
#
# Epoch 00297: val_loss did not improve from 0.10434
#
# Epoch 00298: val_loss did not improve from 0.10434
#
# Epoch 00299: val_loss improved from 0.10434 to 0.10039, saving model to ./model/299-0.1004.hdf5
#
# Epoch 00300: val_loss did not improve from 0.10039
#
# Epoch 00301: val_loss did not improve from 0.10039
#
# Epoch 00302: val_loss did not improve from 0.10039
#
# Epoch 00303: val_loss did not improve from 0.10039
#
# Epoch 00304: val_loss did not improve from 0.10039
#
# Epoch 00305: val_loss did not improve from 0.10039
#
# Epoch 00306: val_loss improved from 0.10039 to 0.09912, saving model to ./model/306-0.0991.hdf5
#
# Epoch 00307: val_loss did not improve from 0.09912
#
# Epoch 00308: val_loss did not improve from 0.09912
#
# Epoch 00309: val_loss did not improve from 0.09912
#
# Epoch 00310: val_loss improved from 0.09912 to 0.09911, saving model to ./model/310-0.0991.hdf5
#
# Epoch 00311: val_loss did not improve from 0.09911
#
# Epoch 00312: val_loss did not improve from 0.09911
#
# Epoch 00313: val_loss did not improve from 0.09911
#
# Epoch 00314: val_loss did not improve from 0.09911
#
# Epoch 00315: val_loss did not improve from 0.09911
#
# Epoch 00316: val_loss did not improve from 0.09911
#
# Epoch 00317: val_loss did not improve from 0.09911
#
# Epoch 00318: val_loss did not improve from 0.09911
#
# Epoch 00319: val_loss did not improve from 0.09911
#
# Epoch 00320: val_loss improved from 0.09911 to 0.09779, saving model to ./model/320-0.0978.hdf5
#
# Epoch 00321: val_loss did not improve from 0.09779
#
# Epoch 00322: val_loss did not improve from 0.09779
#
# Epoch 00323: val_loss improved from 0.09779 to 0.09589, saving model to ./model/323-0.0959.hdf5
#
# Epoch 00324: val_loss did not improve from 0.09589
#
# Epoch 00325: val_loss did not improve from 0.09589
#
# Epoch 00326: val_loss did not improve from 0.09589
#
# Epoch 00327: val_loss did not improve from 0.09589
#
# Epoch 00328: val_loss did not improve from 0.09589
#
# Epoch 00329: val_loss did not improve from 0.09589
#
# Epoch 00330: val_loss improved from 0.09589 to 0.09412, saving model to ./model/330-0.0941.hdf5
#
# Epoch 00331: val_loss did not improve from 0.09412
#
# Epoch 00332: val_loss did not improve from 0.09412
#
# Epoch 00333: val_loss did not improve from 0.09412
#
# Epoch 00334: val_loss improved from 0.09412 to 0.09384, saving model to ./model/334-0.0938.hdf5
#
# Epoch 00335: val_loss did not improve from 0.09384
#
# Epoch 00336: val_loss did not improve from 0.09384
#
# Epoch 00337: val_loss improved from 0.09384 to 0.09201, saving model to ./model/337-0.0920.hdf5
#
# Epoch 00338: val_loss did not improve from 0.09201
#
# Epoch 00339: val_loss did not improve from 0.09201
#
# Epoch 00340: val_loss did not improve from 0.09201
#
# Epoch 00341: val_loss did not improve from 0.09201
#
# Epoch 00342: val_loss did not improve from 0.09201
#
# Epoch 00343: val_loss did not improve from 0.09201
#
# Epoch 00344: val_loss did not improve from 0.09201
#
# Epoch 00345: val_loss did not improve from 0.09201
#
# Epoch 00346: val_loss did not improve from 0.09201
#
# Epoch 00347: val_loss did not improve from 0.09201
#
# Epoch 00348: val_loss did not improve from 0.09201
#
# Epoch 00349: val_loss did not improve from 0.09201
#
# Epoch 00350: val_loss did not improve from 0.09201
#
# Epoch 00351: val_loss did not improve from 0.09201
#
# Epoch 00352: val_loss did not improve from 0.09201
#
# Epoch 00353: val_loss did not improve from 0.09201
#
# Epoch 00354: val_loss did not improve from 0.09201
#
# Epoch 00355: val_loss did not improve from 0.09201
#
# Epoch 00356: val_loss improved from 0.09201 to 0.09077, saving model to ./model/356-0.0908.hdf5
#
# Epoch 00357: val_loss did not improve from 0.09077
#
# Epoch 00358: val_loss did not improve from 0.09077
#
# Epoch 00359: val_loss did not improve from 0.09077
#
# Epoch 00360: val_loss did not improve from 0.09077
#
# Epoch 00361: val_loss did not improve from 0.09077
#
# Epoch 00362: val_loss improved from 0.09077 to 0.08943, saving model to ./model/362-0.0894.hdf5
#
# Epoch 00363: val_loss did not improve from 0.08943
#
# Epoch 00364: val_loss did not improve from 0.08943
#
# Epoch 00365: val_loss did not improve from 0.08943
#
# Epoch 00366: val_loss did not improve from 0.08943
#
# Epoch 00367: val_loss did not improve from 0.08943
#
# Epoch 00368: val_loss did not improve from 0.08943
#
# Epoch 00369: val_loss did not improve from 0.08943
#
# Epoch 00370: val_loss improved from 0.08943 to 0.08692, saving model to ./model/370-0.0869.hdf5
#
# Epoch 00371: val_loss did not improve from 0.08692
#
# Epoch 00372: val_loss did not improve from 0.08692
#
# Epoch 00373: val_loss did not improve from 0.08692
#
# Epoch 00374: val_loss improved from 0.08692 to 0.08527, saving model to ./model/374-0.0853.hdf5
#
# Epoch 00375: val_loss did not improve from 0.08527
#
# Epoch 00376: val_loss did not improve from 0.08527
#
# Epoch 00377: val_loss did not improve from 0.08527
#
# Epoch 00378: val_loss did not improve from 0.08527
#
# Epoch 00379: val_loss did not improve from 0.08527
#
# Epoch 00380: val_loss did not improve from 0.08527
#
# Epoch 00381: val_loss did not improve from 0.08527
#
# Epoch 00382: val_loss improved from 0.08527 to 0.08473, saving model to ./model/382-0.0847.hdf5
# Epoch 00383: val_loss did not improve from 0.08473
#
# Epoch 00384: val_loss did not improve from 0.08473
#
# Epoch 00385: val_loss did not improve from 0.08473
#
# Epoch 00386: val_loss improved from 0.08473 to 0.08396, saving model to ./model/386-0.0840.hdf5
#
# Epoch 00387: val_loss did not improve from 0.08396
#
# Epoch 00388: val_loss did not improve from 0.08396
#
# Epoch 00389: val_loss did not improve from 0.08396
#
# Epoch 00390: val_loss improved from 0.08396 to 0.08370, saving model to ./model/390-0.0837.hdf5
#
# Epoch 00391: val_loss did not improve from 0.08370
#
# Epoch 00392: val_loss did not improve from 0.08370
#
# Epoch 00393: val_loss did not improve from 0.08370
#
# Epoch 00394: val_loss improved from 0.08370 to 0.08355, saving model to ./model/394-0.0836.hdf5
#
# Epoch 00395: val_loss did not improve from 0.08355
#
# Epoch 00396: val_loss did not improve from 0.08355
#
# Epoch 00397: val_loss improved from 0.08355 to 0.08106, saving model to ./model/397-0.0811.hdf5
#
# Epoch 00398: val_loss did not improve from 0.08106
#
# Epoch 00399: val_loss did not improve from 0.08106
#
# Epoch 00400: val_loss did not improve from 0.08106
#
# Epoch 00401: val_loss did not improve from 0.08106
#
# Epoch 00402: val_loss did not improve from 0.08106
#
# Epoch 00403: val_loss did not improve from 0.08106
#
# Epoch 00404: val_loss did not improve from 0.08106
#
# Epoch 00405: val_loss did not improve from 0.08106
#
# Epoch 00406: val_loss did not improve from 0.08106
#
# Epoch 00407: val_loss improved from 0.08106 to 0.08014, saving model to ./model/407-0.0801.hdf5
#
# Epoch 00408: val_loss did not improve from 0.08014
#
# Epoch 00409: val_loss did not improve from 0.08014
#
# Epoch 00410: val_loss did not improve from 0.08014
#
# Epoch 00411: val_loss did not improve from 0.08014
#
# Epoch 00412: val_loss did not improve from 0.08014
#
# Epoch 00413: val_loss did not improve from 0.08014
#
# Epoch 00414: val_loss did not improve from 0.08014
#
# Epoch 00415: val_loss did not improve from 0.08014
#
# Epoch 00416: val_loss did not improve from 0.08014
#
# Epoch 00417: val_loss did not improve from 0.08014
#
# Epoch 00418: val_loss improved from 0.08014 to 0.07966, saving model to ./model/418-0.0797.hdf5
#
# Epoch 00419: val_loss did not improve from 0.07966
#
# Epoch 00420: val_loss did not improve from 0.07966
#
# Epoch 00421: val_loss improved from 0.07966 to 0.07742, saving model to ./model/421-0.0774.hdf5
#
# Epoch 00422: val_loss did not improve from 0.07742
#
# Epoch 00423: val_loss did not improve from 0.07742
#
# Epoch 00424: val_loss did not improve from 0.07742
#
# Epoch 00425: val_loss improved from 0.07742 to 0.07624, saving model to ./model/425-0.0762.hdf5
#
# Epoch 00426: val_loss did not improve from 0.07624
#
# Epoch 00427: val_loss did not improve from 0.07624
#
# Epoch 00428: val_loss did not improve from 0.07624
#
# Epoch 00429: val_loss improved from 0.07624 to 0.07619, saving model to ./model/429-0.0762.hdf5
#
# Epoch 00430: val_loss did not improve from 0.07619
#
# Epoch 00431: val_loss did not improve from 0.07619
#
# Epoch 00432: val_loss improved from 0.07619 to 0.07561, saving model to ./model/432-0.0756.hdf5
#
# Epoch 00433: val_loss did not improve from 0.07561
#
# Epoch 00434: val_loss did not improve from 0.07561
#
# Epoch 00435: val_loss did not improve from 0.07561
#
# Epoch 00436: val_loss did not improve from 0.07561
#
# Epoch 00437: val_loss did not improve from 0.07561
#
# Epoch 00438: val_loss did not improve from 0.07561
#
# Epoch 00439: val_loss improved from 0.07561 to 0.07503, saving model to ./model/439-0.0750.hdf5
#
# Epoch 00440: val_loss did not improve from 0.07503
#
# Epoch 00441: val_loss did not improve from 0.07503
#
# Epoch 00442: val_loss did not improve from 0.07503
#
# Epoch 00443: val_loss did not improve from 0.07503
#
# Epoch 00444: val_loss did not improve from 0.07503
#
# Epoch 00445: val_loss did not improve from 0.07503
#
# Epoch 00446: val_loss did not improve from 0.07503
#
# Epoch 00447: val_loss did not improve from 0.07503
#
# Epoch 00448: val_loss improved from 0.07503 to 0.07360, saving model to ./model/448-0.0736.hdf5
#
# Epoch 00449: val_loss did not improve from 0.07360
#
# Epoch 00450: val_loss did not improve from 0.07360
#
# Epoch 00451: val_loss did not improve from 0.07360
#
# Epoch 00452: val_loss improved from 0.07360 to 0.07324, saving model to ./model/452-0.0732.hdf5
#
# Epoch 00453: val_loss did not improve from 0.07324
#
# Epoch 00454: val_loss did not improve from 0.07324
#
# Epoch 00455: val_loss did not improve from 0.07324
#
# Epoch 00456: val_loss did not improve from 0.07324
#
# Epoch 00457: val_loss did not improve from 0.07324
#
# Epoch 00458: val_loss did not improve from 0.07324
#
# Epoch 00459: val_loss improved from 0.07324 to 0.07233, saving model to ./model/459-0.0723.hdf5
#
# Epoch 00460: val_loss did not improve from 0.07233
#
# Epoch 00461: val_loss did not improve from 0.07233
#
# Epoch 00462: val_loss did not improve from 0.07233
#
# Epoch 00463: val_loss did not improve from 0.07233
#
# Epoch 00464: val_loss did not improve from 0.07233
#
# Epoch 00465: val_loss did not improve from 0.07233
#
# Epoch 00466: val_loss did not improve from 0.07233
#
# Epoch 00467: val_loss did not improve from 0.07233
#
# Epoch 00468: val_loss did not improve from 0.07233
#
# Epoch 00469: val_loss improved from 0.07233 to 0.07181, saving model to ./model/469-0.0718.hdf5
#
# Epoch 00470: val_loss did not improve from 0.07181
#
# Epoch 00471: val_loss did not improve from 0.07181
#
# Epoch 00472: val_loss did not improve from 0.07181
#
# Epoch 00473: val_loss did not improve from 0.07181
#
# Epoch 00474: val_loss did not improve from 0.07181
#
# Epoch 00475: val_loss improved from 0.07181 to 0.07045, saving model to ./model/475-0.0705.hdf5
#
# Epoch 00476: val_loss did not improve from 0.07045
#
# Epoch 00477: val_loss did not improve from 0.07045
#
# Epoch 00478: val_loss did not improve from 0.07045
#
# Epoch 00479: val_loss did not improve from 0.07045
#
# Epoch 00480: val_loss did not improve from 0.07045
#
# Epoch 00481: val_loss did not improve from 0.07045
#
# Epoch 00482: val_loss did not improve from 0.07045
#
# Epoch 00483: val_loss did not improve from 0.07045
#
# Epoch 00484: val_loss did not improve from 0.07045
#
# Epoch 00485: val_loss did not improve from 0.07045
#
# Epoch 00486: val_loss did not improve from 0.07045
#
# Epoch 00487: val_loss did not improve from 0.07045
#
# Epoch 00488: val_loss did not improve from 0.07045
#
# Epoch 00489: val_loss did not improve from 0.07045
#
# Epoch 00490: val_loss did not improve from 0.07045
#
# Epoch 00491: val_loss did not improve from 0.07045
#
# Epoch 00492: val_loss improved from 0.07045 to 0.07023, saving model to ./model/492-0.0702.hdf5
#
# Epoch 00493: val_loss did not improve from 0.07023
#
# Epoch 00494: val_loss did not improve from 0.07023
#
# Epoch 00495: val_loss improved from 0.07023 to 0.07017, saving model to ./model/495-0.0702.hdf5
#
# Epoch 00496: val_loss did not improve from 0.07017
#
# Epoch 00497: val_loss did not improve from 0.07017
#
# Epoch 00498: val_loss improved from 0.07017 to 0.06853, saving model to ./model/498-0.0685.hdf5
#
# Epoch 00499: val_loss did not improve from 0.06853
#
# Epoch 00500: val_loss did not improve from 0.06853
#
# Epoch 00501: val_loss did not improve from 0.06853
#
# Epoch 00502: val_loss improved from 0.06853 to 0.06776, saving model to ./model/502-0.0678.hdf5
#
# Epoch 00503: val_loss did not improve from 0.06776
#
# Epoch 00504: val_loss did not improve from 0.06776
#
# Epoch 00505: val_loss did not improve from 0.06776
#
# Epoch 00506: val_loss improved from 0.06776 to 0.06759, saving model to ./model/506-0.0676.hdf5
#
# Epoch 00507: val_loss did not improve from 0.06759
#
# Epoch 00508: val_loss did not improve from 0.06759
#
# Epoch 00509: val_loss did not improve from 0.06759
#
# Epoch 00510: val_loss did not improve from 0.06759
#
# Epoch 00511: val_loss did not improve from 0.06759
#
# Epoch 00512: val_loss did not improve from 0.06759
#
# Epoch 00513: val_loss did not improve from 0.06759
#
# Epoch 00514: val_loss did not improve from 0.06759
#
# Epoch 00515: val_loss did not improve from 0.06759
#
# Epoch 00516: val_loss did not improve from 0.06759
#
# Epoch 00517: val_loss did not improve from 0.06759
#
# Epoch 00518: val_loss did not improve from 0.06759
#
# Epoch 00519: val_loss did not improve from 0.06759
#
# Epoch 00520: val_loss did not improve from 0.06759
#
# Epoch 00521: val_loss did not improve from 0.06759
#
# Epoch 00522: val_loss did not improve from 0.06759
#
# Epoch 00523: val_loss improved from 0.06759 to 0.06642, saving model to ./model/523-0.0664.hdf5
# Epoch 00524: val_loss did not improve from 0.06642
#
# Epoch 00525: val_loss did not improve from 0.06642
#
# Epoch 00526: val_loss did not improve from 0.06642
#
# Epoch 00527: val_loss did not improve from 0.06642
#
# Epoch 00528: val_loss did not improve from 0.06642
#
# Epoch 00529: val_loss did not improve from 0.06642
#
# Epoch 00530: val_loss improved from 0.06642 to 0.06580, saving model to ./model/530-0.0658.hdf5
#
# Epoch 00531: val_loss did not improve from 0.06580
#
# Epoch 00532: val_loss did not improve from 0.06580
#
# Epoch 00533: val_loss did not improve from 0.06580
#
# Epoch 00534: val_loss did not improve from 0.06580
#
# Epoch 00535: val_loss did not improve from 0.06580
#
# Epoch 00536: val_loss did not improve from 0.06580
#
# Epoch 00537: val_loss did not improve from 0.06580
#
# Epoch 00538: val_loss did not improve from 0.06580
#
# Epoch 00539: val_loss did not improve from 0.06580
#
# Epoch 00540: val_loss did not improve from 0.06580
#
# Epoch 00541: val_loss did not improve from 0.06580
#
# Epoch 00542: val_loss did not improve from 0.06580
#
# Epoch 00543: val_loss did not improve from 0.06580
#
# Epoch 00544: val_loss did not improve from 0.06580
#
# Epoch 00545: val_loss did not improve from 0.06580
#
# Epoch 00546: val_loss did not improve from 0.06580
#
# Epoch 00547: val_loss did not improve from 0.06580
#
# Epoch 00548: val_loss did not improve from 0.06580
#
# Epoch 00549: val_loss did not improve from 0.06580
#
# Epoch 00550: val_loss did not improve from 0.06580
#
# Epoch 00551: val_loss did not improve from 0.06580
#
# Epoch 00552: val_loss did not improve from 0.06580
#
# Epoch 00553: val_loss did not improve from 0.06580
#
# Epoch 00554: val_loss did not improve from 0.06580
#
# Epoch 00555: val_loss did not improve from 0.06580
#
# Epoch 00556: val_loss did not improve from 0.06580
#
# Epoch 00557: val_loss did not improve from 0.06580
#
# Epoch 00558: val_loss did not improve from 0.06580
#
# Epoch 00559: val_loss did not improve from 0.06580
#
# Epoch 00560: val_loss did not improve from 0.06580
#
# Epoch 00561: val_loss did not improve from 0.06580
#
# Epoch 00562: val_loss did not improve from 0.06580
#
# Epoch 00563: val_loss did not improve from 0.06580
#
# Epoch 00564: val_loss did not improve from 0.06580
#
# Epoch 00565: val_loss did not improve from 0.06580
#
# Epoch 00566: val_loss did not improve from 0.06580
#
# Epoch 00567: val_loss did not improve from 0.06580
#
# Epoch 00568: val_loss did not improve from 0.06580
#
# Epoch 00569: val_loss did not improve from 0.06580
#
# Epoch 00570: val_loss did not improve from 0.06580
#
# Epoch 00571: val_loss did not improve from 0.06580
#
# Epoch 00572: val_loss did not improve from 0.06580
#
# Epoch 00573: val_loss did not improve from 0.06580
#
# Epoch 00574: val_loss improved from 0.06580 to 0.06460, saving model to ./model/574-0.0646.hdf5
#
# Epoch 00575: val_loss did not improve from 0.06460
#
# Epoch 00576: val_loss did not improve from 0.06460
#
# Epoch 00577: val_loss did not improve from 0.06460
#
# Epoch 00578: val_loss did not improve from 0.06460
#
# Epoch 00579: val_loss did not improve from 0.06460
#
# Epoch 00580: val_loss did not improve from 0.06460
#
# Epoch 00581: val_loss did not improve from 0.06460
#
# Epoch 00582: val_loss did not improve from 0.06460
#
# Epoch 00583: val_loss did not improve from 0.06460
#
# Epoch 00584: val_loss did not improve from 0.06460
#
# Epoch 00585: val_loss did not improve from 0.06460
#
# Epoch 00586: val_loss did not improve from 0.06460
#
# Epoch 00587: val_loss did not improve from 0.06460
#
# Epoch 00588: val_loss did not improve from 0.06460
#
# Epoch 00589: val_loss did not improve from 0.06460
#
# Epoch 00590: val_loss did not improve from 0.06460
#
# Epoch 00591: val_loss did not improve from 0.06460
#
# Epoch 00592: val_loss did not improve from 0.06460
#
# Epoch 00593: val_loss did not improve from 0.06460
#
# Epoch 00594: val_loss did not improve from 0.06460
#
# Epoch 00595: val_loss did not improve from 0.06460
#
# Epoch 00596: val_loss did not improve from 0.06460
#
# Epoch 00597: val_loss did not improve from 0.06460
#
# Epoch 00598: val_loss improved from 0.06460 to 0.06449, saving model to ./model/598-0.0645.hdf5
#
# Epoch 00599: val_loss did not improve from 0.06449
#
# Epoch 00600: val_loss did not improve from 0.06449
#
# Epoch 00601: val_loss did not improve from 0.06449
#
# Epoch 00602: val_loss did not improve from 0.06449
#
# Epoch 00603: val_loss did not improve from 0.06449
#
# Epoch 00604: val_loss improved from 0.06449 to 0.06359, saving model to ./model/604-0.0636.hdf5
#
# Epoch 00605: val_loss did not improve from 0.06359
#
# Epoch 00606: val_loss did not improve from 0.06359
#
# Epoch 00607: val_loss did not improve from 0.06359
#
# Epoch 00608: val_loss did not improve from 0.06359
#
# Epoch 00609: val_loss did not improve from 0.06359
#
# Epoch 00610: val_loss did not improve from 0.06359
#
# Epoch 00611: val_loss improved from 0.06359 to 0.06299, saving model to ./model/611-0.0630.hdf5
#
# Epoch 00612: val_loss did not improve from 0.06299
#
# Epoch 00613: val_loss did not improve from 0.06299
#
# Epoch 00614: val_loss improved from 0.06299 to 0.06298, saving model to ./model/614-0.0630.hdf5
#
# Epoch 00615: val_loss did not improve from 0.06298
#
# Epoch 00616: val_loss did not improve from 0.06298
#
# Epoch 00617: val_loss improved from 0.06298 to 0.06293, saving model to ./model/617-0.0629.hdf5
#
# Epoch 00618: val_loss improved from 0.06293 to 0.06244, saving model to ./model/618-0.0624.hdf5
#
# Epoch 00619: val_loss did not improve from 0.06244
#
# Epoch 00620: val_loss did not improve from 0.06244
#
# Epoch 00621: val_loss did not improve from 0.06244
#
# Epoch 00622: val_loss did not improve from 0.06244
#
# Epoch 00623: val_loss did not improve from 0.06244
#
# Epoch 00624: val_loss did not improve from 0.06244
#
# Epoch 00625: val_loss improved from 0.06244 to 0.06105, saving model to ./model/625-0.0611.hdf5
#
# Epoch 00626: val_loss did not improve from 0.06105
#
# Epoch 00627: val_loss did not improve from 0.06105
#
# Epoch 00628: val_loss did not improve from 0.06105
#
# Epoch 00629: val_loss did not improve from 0.06105
#
# Epoch 00630: val_loss did not improve from 0.06105
#
# Epoch 00631: val_loss did not improve from 0.06105
#
# Epoch 00632: val_loss did not improve from 0.06105
#
# Epoch 00633: val_loss did not improve from 0.06105
#
# Epoch 00634: val_loss did not improve from 0.06105
#
# Epoch 00635: val_loss did not improve from 0.06105
#
# Epoch 00636: val_loss did not improve from 0.06105
#
# Epoch 00637: val_loss did not improve from 0.06105
#
# Epoch 00638: val_loss did not improve from 0.06105
#
# Epoch 00639: val_loss did not improve from 0.06105
#
# Epoch 00640: val_loss did not improve from 0.06105
#
# Epoch 00641: val_loss did not improve from 0.06105
#
# Epoch 00642: val_loss did not improve from 0.06105
#
# Epoch 00643: val_loss did not improve from 0.06105
#
# Epoch 00644: val_loss did not improve from 0.06105
#
# Epoch 00645: val_loss improved from 0.06105 to 0.06056, saving model to ./model/645-0.0606.hdf5
#
# Epoch 00646: val_loss did not improve from 0.06056
#
# Epoch 00647: val_loss did not improve from 0.06056
#
# Epoch 00648: val_loss did not improve from 0.06056
#
# Epoch 00649: val_loss did not improve from 0.06056
#
# Epoch 00650: val_loss did not improve from 0.06056
#
# Epoch 00651: val_loss did not improve from 0.06056
#
# Epoch 00652: val_loss did not improve from 0.06056
#
# Epoch 00653: val_loss did not improve from 0.06056
#
# Epoch 00654: val_loss did not improve from 0.06056
#
# Epoch 00655: val_loss did not improve from 0.06056
#
# Epoch 00656: val_loss improved from 0.06056 to 0.06037, saving model to ./model/656-0.0604.hdf5
#
# Epoch 00657: val_loss did not improve from 0.06037
#
# Epoch 00658: val_loss did not improve from 0.06037
#
# Epoch 00659: val_loss did not improve from 0.06037
#
# Epoch 00660: val_loss did not improve from 0.06037
#
# Epoch 00661: val_loss did not improve from 0.06037
#
# Epoch 00662: val_loss improved from 0.06037 to 0.05658, saving model to ./model/662-0.0566.hdf5
#
# Epoch 00663: val_loss did not improve from 0.05658
#
# Epoch 00664: val_loss did not improve from 0.05658
#
# Epoch 00665: val_loss improved from 0.05658 to 0.05572, saving model to ./model/665-0.0557.hdf5
#
# Epoch 00666: val_loss did not improve from 0.05572
#
# Epoch 00667: val_loss did not improve from 0.05572
#
# Epoch 00668: val_loss improved from 0.05572 to 0.05477, saving model to ./model/668-0.0548.hdf5
#
# Epoch 00669: val_loss improved from 0.05477 to 0.05308, saving model to ./model/669-0.0531.hdf5
# Epoch 00670: val_loss did not improve from 0.05308
#
# Epoch 00671: val_loss did not improve from 0.05308
#
# Epoch 00672: val_loss did not improve from 0.05308
#
# Epoch 00673: val_loss did not improve from 0.05308
#
# Epoch 00674: val_loss did not improve from 0.05308
#
# Epoch 00675: val_loss did not improve from 0.05308
#
# Epoch 00676: val_loss did not improve from 0.05308
#
# Epoch 00677: val_loss improved from 0.05308 to 0.05302, saving model to ./model/677-0.0530.hdf5
#
# Epoch 00678: val_loss did not improve from 0.05302
#
# Epoch 00679: val_loss did not improve from 0.05302
#
# Epoch 00680: val_loss did not improve from 0.05302
#
# Epoch 00681: val_loss did not improve from 0.05302
#
# Epoch 00682: val_loss did not improve from 0.05302
#
# Epoch 00683: val_loss did not improve from 0.05302
#
# Epoch 00684: val_loss did not improve from 0.05302
#
# Epoch 00685: val_loss did not improve from 0.05302
#
# Epoch 00686: val_loss did not improve from 0.05302
#
# Epoch 00687: val_loss did not improve from 0.05302
#
# Epoch 00688: val_loss did not improve from 0.05302
#
# Epoch 00689: val_loss did not improve from 0.05302
#
# Epoch 00690: val_loss did not improve from 0.05302
#
# Epoch 00691: val_loss did not improve from 0.05302
#
# Epoch 00692: val_loss did not improve from 0.05302
#
# Epoch 00693: val_loss did not improve from 0.05302
#
# Epoch 00694: val_loss did not improve from 0.05302
#
# Epoch 00695: val_loss did not improve from 0.05302
#
# Epoch 00696: val_loss did not improve from 0.05302
#
# Epoch 00697: val_loss did not improve from 0.05302
#
# Epoch 00698: val_loss did not improve from 0.05302
#
# Epoch 00699: val_loss did not improve from 0.05302
#
# Epoch 00700: val_loss did not improve from 0.05302
#
# Epoch 00701: val_loss did not improve from 0.05302
#
# Epoch 00702: val_loss did not improve from 0.05302
#
# Epoch 00703: val_loss did not improve from 0.05302
#
# Epoch 00704: val_loss did not improve from 0.05302
#
# Epoch 00705: val_loss did not improve from 0.05302
#
# Epoch 00706: val_loss did not improve from 0.05302
#
# Epoch 00707: val_loss did not improve from 0.05302
#
# Epoch 00708: val_loss did not improve from 0.05302
#
# Epoch 00709: val_loss did not improve from 0.05302
#
# Epoch 00710: val_loss did not improve from 0.05302
#
# Epoch 00711: val_loss did not improve from 0.05302
#
# Epoch 00712: val_loss did not improve from 0.05302
#
# Epoch 00713: val_loss did not improve from 0.05302
#
# Epoch 00714: val_loss did not improve from 0.05302
#
# Epoch 00715: val_loss did not improve from 0.05302
#
# Epoch 00716: val_loss did not improve from 0.05302
#
# Epoch 00717: val_loss did not improve from 0.05302
#
# Epoch 00718: val_loss did not improve from 0.05302
#
# Epoch 00719: val_loss did not improve from 0.05302
#
# Epoch 00720: val_loss did not improve from 0.05302
#
# Epoch 00721: val_loss did not improve from 0.05302
#
# Epoch 00722: val_loss did not improve from 0.05302
#
# Epoch 00723: val_loss did not improve from 0.05302
#
# Epoch 00724: val_loss did not improve from 0.05302
#
# Epoch 00725: val_loss did not improve from 0.05302
#
# Epoch 00726: val_loss did not improve from 0.05302
#
# Epoch 00727: val_loss did not improve from 0.05302
#
# Epoch 00728: val_loss did not improve from 0.05302
#
# Epoch 00729: val_loss did not improve from 0.05302
#
# Epoch 00730: val_loss did not improve from 0.05302
#
# Epoch 00731: val_loss did not improve from 0.05302
#
# Epoch 00732: val_loss did not improve from 0.05302
#
# Epoch 00733: val_loss did not improve from 0.05302
#
# Epoch 00734: val_loss did not improve from 0.05302
#
# Epoch 00735: val_loss did not improve from 0.05302
#
# Epoch 00736: val_loss did not improve from 0.05302
#
# Epoch 00737: val_loss did not improve from 0.05302
#
# Epoch 00738: val_loss did not improve from 0.05302
#
# Epoch 00739: val_loss did not improve from 0.05302
#
# Epoch 00740: val_loss did not improve from 0.05302
#
# Epoch 00741: val_loss did not improve from 0.05302
#
# Epoch 00742: val_loss did not improve from 0.05302
#
# Epoch 00743: val_loss did not improve from 0.05302
#
# Epoch 00744: val_loss did not improve from 0.05302
#
# Epoch 00745: val_loss did not improve from 0.05302
#
# Epoch 00746: val_loss did not improve from 0.05302
#
# Epoch 00747: val_loss did not improve from 0.05302
#
# Epoch 00748: val_loss did not improve from 0.05302
#
# Epoch 00749: val_loss did not improve from 0.05302
#
# Epoch 00750: val_loss did not improve from 0.05302
#
# Epoch 00751: val_loss did not improve from 0.05302
#
# Epoch 00752: val_loss did not improve from 0.05302
#
# Epoch 00753: val_loss did not improve from 0.05302
#
# Epoch 00754: val_loss did not improve from 0.05302
#
# Epoch 00755: val_loss did not improve from 0.05302
#
# Epoch 00756: val_loss did not improve from 0.05302
#
# Epoch 00757: val_loss did not improve from 0.05302
#
# Epoch 00758: val_loss did not improve from 0.05302
#
# Epoch 00759: val_loss did not improve from 0.05302
#
# Epoch 00760: val_loss did not improve from 0.05302
#
# Epoch 00761: val_loss did not improve from 0.05302
#
# Epoch 00762: val_loss did not improve from 0.05302
#
# Epoch 00763: val_loss did not improve from 0.05302
#
# Epoch 00764: val_loss did not improve from 0.05302
#
# Epoch 00765: val_loss did not improve from 0.05302
#
# Epoch 00766: val_loss did not improve from 0.05302
#
# Epoch 00767: val_loss did not improve from 0.05302
#
# Epoch 00768: val_loss did not improve from 0.05302
#
# Epoch 00769: val_loss did not improve from 0.05302
#
# Epoch 00770: val_loss did not improve from 0.05302
#
# Epoch 00771: val_loss did not improve from 0.05302
#
# Epoch 00772: val_loss did not improve from 0.05302
#
# Epoch 00773: val_loss did not improve from 0.05302
#
# Epoch 00774: val_loss did not improve from 0.05302
#
# Epoch 00775: val_loss did not improve from 0.05302
#
# Epoch 00776: val_loss did not improve from 0.05302
#
# Epoch 00777: val_loss did not improve from 0.05302
