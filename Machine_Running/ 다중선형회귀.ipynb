# %%
import statsmodels.api
import numpy

def main():
    (N, X, Y) = read_data()

    results = do_multivariate_regression(N, X, Y)
    print(results.summary())

    effective_variables = get_effective_variables(results)
    print(effective_variables)

def do_multivariate_regression(N, X, Y):
    
    results = statsmodels.api.OLS(Y, X).fit()
    return results


def get_effective_variables(results):
    eff_vars = []
    print(results.pvalues)
    print(results.params)
    

    return eff_vars

def read_data():
    # 1
    N = 30
    X = [
        [6.09589041096, 292.0, 2.41635687732, 41.0, 4.24050632911], 
         [5.125, 54.0, 1.84, 11.0, 2.125], 
         [7.92307692308, 78.0, 2.06666666667, 24.0, 2.8], 
         [8.3, 61.0, 2.49090909091, 44.0, 2.48275862069], 
         [7.5, 6.0, 3.375, 0.0, 4.33333333333], 
         [7.84615384615, 26.0, 2.23333333333, 18.0, 2.05555555556], 
         [7.57142857143, 14.0, 2.0, 3.0, 3.42857142857], 
         [7.49180327869, 93.0, 1.92537313433, 78.0, 4.44444444444], 
         [7.90769230769, 140.0, 2.1308411215, 71.0, 3.025], 
         [8.14893617021, 193.0, 2.4696969697, 34.0, 4.21428571429], 
         [5.58333333333, 24.0, 1.95, 6.0, 2.72727272727], 
         [5.90909090909, 57.0, 1.875, 26.0, 1.95454545455], 
         [7.0, 117.0, 1.8, 47.0, 2.76744186047], 
         [4.9, 228.0, 2.85714285714, 25.0, 2.45161290323], 
         [6.85365853659, 140.0, 2.89655172414, 39.0, 3.90625], 
         [7.30434782609, 55.0, 2.46341463415, 10.0, 2.53846153846], 
         [7.69565217391, 44.0, 1.94871794872, 17.0, 4.08],
         [7.11764705882, 62.0, 2.93333333333, 10.0, 3.76470588235],
         [6.47058823529, 72.0, 1.86046511628, 49.0, 3.07407407407], 
         [7.78723404255, 136.0, 2.39622641509, 34.0, 3.13333333333],
         [8.0, 8.0, 3.0, 0.0, 3.0],
         [7.48, 123.0, 1.88311688312, 34.0, 3.11363636364],
         [7.4, 31.0, 2.65, 20.0, 3.07142857143], 
         [7.31578947368, 48.0, 1.5, 23.0, 4.4], 
         [7.04166666667, 87.0, 3.24528301887, 31.0, 3.25], 
         [6.96666666667, 83.0, 2.16216216216, 8.0, 3.23076923077], 
         [6.26086956522, 49.0, 2.69696969697, 22.0, 3.76470588235],
         [7.22222222222, 64.0, 2.25, 7.0, 3.5],
         [6.80487804878, 203.0, 3.3606557377, 38.0, 3.42424242424],
         [7.83636363636, 323.0, 1.97802197802, 122.0, 3.48717948718]
        ]
    
    Y = [3.519, 3.719, 3.505, 3.889, 3.679, 3.245, 3.652, 3.389, 3.373, 3.826, 3.343, 3.474, 3.705, 3.476, 2.815, 2.4, 2.987, 3.93, 3.029, 3.667, 3.806, 3.79, 2.765, 2.815, 3.474, 3.293, 3.646, 2.863, 3.625, 3.947]
    
    
    
    
    X = numpy.array(X)
    Y = numpy.array(Y)
    return (N, X, Y)

if __name__ == "__main__":
    main()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.978
# Method:                 Least Squares   F-statistic:                     266.1
# Date:                Sat, 27 Aug 2016   Prob (F-statistic):           7.84e-21
# Time:                        22:12:17   Log-Likelihood:                -19.767
# No. Observations:                  30   AIC:                             49.53
# Df Residuals:                      25   BIC:                             56.54
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.3387      0.085      3.999      0.000         0.164     0.513
# ...
