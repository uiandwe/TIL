# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping

import pandas as pd
import numpy
import tensorflow as tf
import matplotlib.pyplot as plt
import os

seed = 0
numpy.random.seed(seed)
tf.set_random_seed(seed)

df_pre = pd.read_csv("wine.csv", header=None)
df = df_pre.sample(frac=1)
dataset = df.values
X = dataset[:, 0:12]
Y = dataset[:,12]

model = Sequential()
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', 
             optimizer='adam',
             metrics=['accuracy'])

MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)
    
modelpath = "./model/{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath = modelpath, monitor='val_loss', verbose=1, save_best_only=True)

model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, verbose=0, callbacks=[checkpointer])

# print("Accuracy: %.4f" % (model.evaluate(X, Y)[1]))
# Out:
# Epoch 00001: val_loss improved from inf to 0.31121, saving model to ./model/01-0.3112.hdf5
#
# Epoch 00002: val_loss improved from 0.31121 to 0.25399, saving model to ./model/02-0.2540.hdf5
#
# Epoch 00003: val_loss improved from 0.25399 to 0.21340, saving model to ./model/03-0.2134.hdf5
#
# Epoch 00004: val_loss improved from 0.21340 to 0.20453, saving model to ./model/04-0.2045.hdf5
#
# Epoch 00005: val_loss improved from 0.20453 to 0.19675, saving model to ./model/05-0.1968.hdf5
#
# Epoch 00006: val_loss improved from 0.19675 to 0.18564, saving model to ./model/06-0.1856.hdf5
#
# Epoch 00007: val_loss improved from 0.18564 to 0.18048, saving model to ./model/07-0.1805.hdf5
#
# Epoch 00008: val_loss improved from 0.18048 to 0.17988, saving model to ./model/08-0.1799.hdf5
#
# Epoch 00009: val_loss improved from 0.17988 to 0.17937, saving model to ./model/09-0.1794.hdf5
#
# Epoch 00010: val_loss improved from 0.17937 to 0.17632, saving model to ./model/10-0.1763.hdf5
#
# Epoch 00011: val_loss improved from 0.17632 to 0.16652, saving model to ./model/11-0.1665.hdf5
#
# Epoch 00012: val_loss improved from 0.16652 to 0.16310, saving model to ./model/12-0.1631.hdf5
#
# Epoch 00013: val_loss did not improve from 0.16310
#
# Epoch 00014: val_loss improved from 0.16310 to 0.15813, saving model to ./model/14-0.1581.hdf5
#
# Epoch 00015: val_loss improved from 0.15813 to 0.15689, saving model to ./model/15-0.1569.hdf5
#
# Epoch 00016: val_loss improved from 0.15689 to 0.15114, saving model to ./model/16-0.1511.hdf5
#
# Epoch 00017: val_loss improved from 0.15114 to 0.14824, saving model to ./model/17-0.1482.hdf5
#
# Epoch 00018: val_loss improved from 0.14824 to 0.14598, saving model to ./model/18-0.1460.hdf5
#
# Epoch 00019: val_loss improved from 0.14598 to 0.14331, saving model to ./model/19-0.1433.hdf5
#
# Epoch 00020: val_loss did not improve from 0.14331
#
# Epoch 00021: val_loss improved from 0.14331 to 0.13687, saving model to ./model/21-0.1369.hdf5
#
# Epoch 00022: val_loss improved from 0.13687 to 0.13398, saving model to ./model/22-0.1340.hdf5
#
# Epoch 00023: val_loss did not improve from 0.13398
#
# Epoch 00024: val_loss improved from 0.13398 to 0.12740, saving model to ./model/24-0.1274.hdf5
#
# Epoch 00025: val_loss improved from 0.12740 to 0.12561, saving model to ./model/25-0.1256.hdf5
#
# Epoch 00026: val_loss improved from 0.12561 to 0.12170, saving model to ./model/26-0.1217.hdf5
#
# Epoch 00027: val_loss improved from 0.12170 to 0.12021, saving model to ./model/27-0.1202.hdf5
#
# Epoch 00028: val_loss improved from 0.12021 to 0.11737, saving model to ./model/28-0.1174.hdf5
#
# Epoch 00029: val_loss did not improve from 0.11737
#
# Epoch 00030: val_loss improved from 0.11737 to 0.11210, saving model to ./model/30-0.1121.hdf5
#
# Epoch 00031: val_loss did not improve from 0.11210
#
# Epoch 00032: val_loss improved from 0.11210 to 0.10923, saving model to ./model/32-0.1092.hdf5
#
# Epoch 00033: val_loss improved from 0.10923 to 0.10542, saving model to ./model/33-0.1054.hdf5
#
# Epoch 00034: val_loss did not improve from 0.10542
#
# Epoch 00035: val_loss improved from 0.10542 to 0.10461, saving model to ./model/35-0.1046.hdf5
#
# Epoch 00036: val_loss improved from 0.10461 to 0.10445, saving model to ./model/36-0.1045.hdf5
#
# Epoch 00037: val_loss improved from 0.10445 to 0.09628, saving model to ./model/37-0.0963.hdf5
#
# Epoch 00038: val_loss improved from 0.09628 to 0.09278, saving model to ./model/38-0.0928.hdf5
#
# Epoch 00039: val_loss improved from 0.09278 to 0.09230, saving model to ./model/39-0.0923.hdf5
#
# Epoch 00040: val_loss did not improve from 0.09230
#
# Epoch 00041: val_loss improved from 0.09230 to 0.08954, saving model to ./model/41-0.0895.hdf5
#
# Epoch 00042: val_loss improved from 0.08954 to 0.08637, saving model to ./model/42-0.0864.hdf5
#
# Epoch 00043: val_loss did not improve from 0.08637
#
# Epoch 00044: val_loss improved from 0.08637 to 0.08615, saving model to ./model/44-0.0861.hdf5
#
# Epoch 00045: val_loss improved from 0.08615 to 0.08563, saving model to ./model/45-0.0856.hdf5
#
# Epoch 00046: val_loss improved from 0.08563 to 0.08272, saving model to ./model/46-0.0827.hdf5
#
# Epoch 00047: val_loss did not improve from 0.08272
#
# Epoch 00048: val_loss did not improve from 0.08272
#
# Epoch 00049: val_loss improved from 0.08272 to 0.07916, saving model to ./model/49-0.0792.hdf5
#
# Epoch 00050: val_loss did not improve from 0.07916
#
# Epoch 00051: val_loss improved from 0.07916 to 0.07730, saving model to ./model/51-0.0773.hdf5
#
# Epoch 00052: val_loss improved from 0.07730 to 0.07596, saving model to ./model/52-0.0760.hdf5
#
# Epoch 00053: val_loss did not improve from 0.07596
#
# Epoch 00054: val_loss did not improve from 0.07596
#
# Epoch 00055: val_loss did not improve from 0.07596
#
# Epoch 00056: val_loss did not improve from 0.07596
#
# Epoch 00057: val_loss improved from 0.07596 to 0.07275, saving model to ./model/57-0.0727.hdf5
#
# Epoch 00058: val_loss did not improve from 0.07275
#
# Epoch 00059: val_loss improved from 0.07275 to 0.07127, saving model to ./model/59-0.0713.hdf5
#
# Epoch 00060: val_loss improved from 0.07127 to 0.06916, saving model to ./model/60-0.0692.hdf5
#
# Epoch 00061: val_loss did not improve from 0.06916
#
# Epoch 00062: val_loss did not improve from 0.06916
#
# Epoch 00063: val_loss improved from 0.06916 to 0.06689, saving model to ./model/63-0.0669.hdf5
#
# Epoch 00064: val_loss did not improve from 0.06689
#
# Epoch 00065: val_loss improved from 0.06689 to 0.06688, saving model to ./model/65-0.0669.hdf5
#
# Epoch 00066: val_loss improved from 0.06688 to 0.06551, saving model to ./model/66-0.0655.hdf5
#
# Epoch 00067: val_loss improved from 0.06551 to 0.06530, saving model to ./model/67-0.0653.hdf5
#
# Epoch 00068: val_loss did not improve from 0.06530
#
# Epoch 00069: val_loss improved from 0.06530 to 0.06507, saving model to ./model/69-0.0651.hdf5
#
# Epoch 00070: val_loss improved from 0.06507 to 0.06463, saving model to ./model/70-0.0646.hdf5
#
# Epoch 00071: val_loss improved from 0.06463 to 0.06333, saving model to ./model/71-0.0633.hdf5
#
# Epoch 00072: val_loss did not improve from 0.06333
#
# Epoch 00073: val_loss did not improve from 0.06333
#
# Epoch 00074: val_loss improved from 0.06333 to 0.06256, saving model to ./model/74-0.0626.hdf5
#
# Epoch 00075: val_loss improved from 0.06256 to 0.06250, saving model to ./model/75-0.0625.hdf5
#
# Epoch 00076: val_loss did not improve from 0.06250
#
# Epoch 00077: val_loss improved from 0.06250 to 0.06167, saving model to ./model/77-0.0617.hdf5
#
# Epoch 00078: val_loss did not improve from 0.06167
#
# Epoch 00079: val_loss did not improve from 0.06167
#
# Epoch 00080: val_loss improved from 0.06167 to 0.06080, saving model to ./model/80-0.0608.hdf5
#
# Epoch 00081: val_loss did not improve from 0.06080
#
# Epoch 00082: val_loss did not improve from 0.06080
#
# Epoch 00083: val_loss did not improve from 0.06080
#
# Epoch 00084: val_loss did not improve from 0.06080
#
# Epoch 00085: val_loss improved from 0.06080 to 0.06003, saving model to ./model/85-0.0600.hdf5
#
# Epoch 00086: val_loss improved from 0.06003 to 0.05949, saving model to ./model/86-0.0595.hdf5
#
# Epoch 00087: val_loss improved from 0.05949 to 0.05771, saving model to ./model/87-0.0577.hdf5
#
# Epoch 00088: val_loss did not improve from 0.05771
#
# Epoch 00089: val_loss did not improve from 0.05771
#
# Epoch 00090: val_loss did not improve from 0.05771
#
# Epoch 00091: val_loss did not improve from 0.05771
#
# Epoch 00092: val_loss did not improve from 0.05771
#
# Epoch 00093: val_loss did not improve from 0.05771
#
# Epoch 00094: val_loss did not improve from 0.05771
#
# Epoch 00095: val_loss improved from 0.05771 to 0.05760, saving model to ./model/95-0.0576.hdf5
#
# Epoch 00096: val_loss did not improve from 0.05760
#
# Epoch 00097: val_loss improved from 0.05760 to 0.05545, saving model to ./model/97-0.0554.hdf5
#
# Epoch 00098: val_loss improved from 0.05545 to 0.05530, saving model to ./model/98-0.0553.hdf5
#
# Epoch 00099: val_loss did not improve from 0.05530
#
# Epoch 00100: val_loss did not improve from 0.05530
#
# Epoch 00101: val_loss did not improve from 0.05530
#
# Epoch 00102: val_loss improved from 0.05530 to 0.05529, saving model to ./model/102-0.0553.hdf5
#
# Epoch 00103: val_loss did not improve from 0.05529
#
# Epoch 00104: val_loss did not improve from 0.05529
#
# Epoch 00105: val_loss did not improve from 0.05529
#
# Epoch 00106: val_loss did not improve from 0.05529
#
# Epoch 00107: val_loss did not improve from 0.05529
#
# Epoch 00108: val_loss did not improve from 0.05529
#
# Epoch 00109: val_loss did not improve from 0.05529
#
# Epoch 00110: val_loss improved from 0.05529 to 0.05519, saving model to ./model/110-0.0552.hdf5
#
# Epoch 00111: val_loss did not improve from 0.05519
#
# Epoch 00112: val_loss did not improve from 0.05519
#
# Epoch 00113: val_loss improved from 0.05519 to 0.05424, saving model to ./model/113-0.0542.hdf5
#
# Epoch 00114: val_loss did not improve from 0.05424
#
# Epoch 00115: val_loss did not improve from 0.05424
#
# Epoch 00116: val_loss did not improve from 0.05424
#
# Epoch 00117: val_loss did not improve from 0.05424
#
# Epoch 00118: val_loss improved from 0.05424 to 0.05380, saving model to ./model/118-0.0538.hdf5
#
# Epoch 00119: val_loss did not improve from 0.05380
#
# Epoch 00120: val_loss did not improve from 0.05380
#
# Epoch 00121: val_loss improved from 0.05380 to 0.05228, saving model to ./model/121-0.0523.hdf5
#
# Epoch 00122: val_loss did not improve from 0.05228
#
# Epoch 00123: val_loss did not improve from 0.05228
#
# Epoch 00124: val_loss did not improve from 0.05228
#
# Epoch 00125: val_loss did not improve from 0.05228
#
# Epoch 00126: val_loss did not improve from 0.05228
#
# Epoch 00127: val_loss did not improve from 0.05228
#
# Epoch 00128: val_loss did not improve from 0.05228
#
# Epoch 00129: val_loss did not improve from 0.05228
#
# Epoch 00130: val_loss did not improve from 0.05228
#
# Epoch 00131: val_loss did not improve from 0.05228
#
# Epoch 00132: val_loss did not improve from 0.05228
#
# Epoch 00133: val_loss did not improve from 0.05228
#
# Epoch 00134: val_loss did not improve from 0.05228
#
# Epoch 00135: val_loss did not improve from 0.05228
#
# Epoch 00136: val_loss did not improve from 0.05228
#
# Epoch 00137: val_loss did not improve from 0.05228
#
# Epoch 00138: val_loss improved from 0.05228 to 0.05167, saving model to ./model/138-0.0517.hdf5
#
# Epoch 00139: val_loss improved from 0.05167 to 0.05052, saving model to ./model/139-0.0505.hdf5
#
# Epoch 00140: val_loss did not improve from 0.05052
#
# Epoch 00141: val_loss did not improve from 0.05052
#
# Epoch 00142: val_loss did not improve from 0.05052
#
# Epoch 00143: val_loss did not improve from 0.05052
#
# Epoch 00144: val_loss did not improve from 0.05052
#
# Epoch 00145: val_loss did not improve from 0.05052
#
# Epoch 00146: val_loss did not improve from 0.05052
#
# Epoch 00147: val_loss did not improve from 0.05052
#
# Epoch 00148: val_loss did not improve from 0.05052
#
# Epoch 00149: val_loss did not improve from 0.05052
#
# Epoch 00150: val_loss did not improve from 0.05052
#
# Epoch 00151: val_loss did not improve from 0.05052
#
# Epoch 00152: val_loss did not improve from 0.05052
#
# Epoch 00153: val_loss did not improve from 0.05052
#
# Epoch 00154: val_loss did not improve from 0.05052
#
# Epoch 00155: val_loss did not improve from 0.05052
#
# Epoch 00156: val_loss did not improve from 0.05052
#
# Epoch 00157: val_loss did not improve from 0.05052
#
# Epoch 00158: val_loss did not improve from 0.05052
#
# Epoch 00159: val_loss did not improve from 0.05052
#
# Epoch 00160: val_loss did not improve from 0.05052
#
# Epoch 00161: val_loss did not improve from 0.05052
#
# Epoch 00162: val_loss did not improve from 0.05052
#
# Epoch 00163: val_loss did not improve from 0.05052
#
# Epoch 00164: val_loss improved from 0.05052 to 0.04999, saving model to ./model/164-0.0500.hdf5
#
# Epoch 00165: val_loss did not improve from 0.04999
#
# Epoch 00166: val_loss did not improve from 0.04999
#
# Epoch 00167: val_loss did not improve from 0.04999
#
# Epoch 00168: val_loss did not improve from 0.04999
#
# Epoch 00169: val_loss did not improve from 0.04999
#
# Epoch 00170: val_loss did not improve from 0.04999
#
# Epoch 00171: val_loss improved from 0.04999 to 0.04960, saving model to ./model/171-0.0496.hdf5
#
# Epoch 00172: val_loss did not improve from 0.04960
#
# Epoch 00173: val_loss did not improve from 0.04960
#
# Epoch 00174: val_loss did not improve from 0.04960
#
# Epoch 00175: val_loss did not improve from 0.04960
#
# Epoch 00176: val_loss did not improve from 0.04960
#
# Epoch 00177: val_loss did not improve from 0.04960
#
# Epoch 00178: val_loss did not improve from 0.04960
#
# Epoch 00179: val_loss did not improve from 0.04960
#
# Epoch 00180: val_loss did not improve from 0.04960
#
# Epoch 00181: val_loss did not improve from 0.04960
#
# Epoch 00182: val_loss did not improve from 0.04960
#
# Epoch 00183: val_loss did not improve from 0.04960
#
# Epoch 00184: val_loss improved from 0.04960 to 0.04951, saving model to ./model/184-0.0495.hdf5
#
# Epoch 00185: val_loss did not improve from 0.04951
#
# Epoch 00186: val_loss did not improve from 0.04951
#
# Epoch 00187: val_loss improved from 0.04951 to 0.04876, saving model to ./model/187-0.0488.hdf5
#
# Epoch 00188: val_loss did not improve from 0.04876
#
# Epoch 00189: val_loss did not improve from 0.04876
#
# Epoch 00190: val_loss did not improve from 0.04876
#
# Epoch 00191: val_loss did not improve from 0.04876
#
# Epoch 00192: val_loss did not improve from 0.04876
#
# Epoch 00193: val_loss did not improve from 0.04876
#
# Epoch 00194: val_loss improved from 0.04876 to 0.04871, saving model to ./model/194-0.0487.hdf5
#
# Epoch 00195: val_loss did not improve from 0.04871
#
# Epoch 00196: val_loss did not improve from 0.04871
#
# Epoch 00197: val_loss did not improve from 0.04871
#
# Epoch 00198: val_loss did not improve from 0.04871
#
# Epoch 00199: val_loss improved from 0.04871 to 0.04861, saving model to ./model/199-0.0486.hdf5
#
# Epoch 00200: val_loss did not improve from 0.04861
